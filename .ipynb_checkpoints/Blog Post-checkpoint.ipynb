# %% [markdown]
# # Here is what you need to know about staying in Boston
#
# Questions:
#
# I. Introduction
#
# II. Money Money Money
#
# III. Location Location Location
#
# IV. Bringing it all together
#
#
#
# * What times of the year are especially expensive? __Check__
# * Which neighborhoods should you visit if you're looking for a quieter or more vibrant experience? __Check__
# * Which neighborhoods are good for a lower-budget vacation? __Check__
# * Is the quality or price different for apartments where the host rents more than 1 rooms?

# %% [markdown]
# ## CRISP-DM Process
#
# 2019 data from dataset on website from 14 September, 2018
#
# 2018 data from dataset on website from 06 October, 2017
#
# 2017 data from dataset on website from 07 September, 2016

# %%
import numpy as np
import csv
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import re
from scipy.stats import pearsonr
from datetime import datetime
from scipy.stats import ttest_ind
from collections import Counter, defaultdict
from wordcloud import WordCloud, STOPWORDS

# %matplotlib inline

# %%
calendar2017 = pd.read_csv('calendar2017.csv', delimiter=',')
calendar2018 = pd.read_csv('calendar2018.csv', delimiter=',')
calendar2019 = pd.read_csv('calendar2019.csv', delimiter=',')

listings = pd.read_csv('listings2017.csv', delimiter=',')
reviews = pd.read_csv('reviews2017.csv', delimiter=',')

# %%
# allow for head to show all column names
pd.set_option('display.max_columns', None) 
listings.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  \
# 0  Roslindale is quiet, convenient and friendly. ...
# 1  The room is in Roslindale, a diverse and prima...
# 2  The LOCATION: Roslindale is a safe and diverse...
# 3  Roslindale is a lovely little neighborhood loc...
# 4  I love the proximity to downtown, the neighbor...
#
#                                                notes  \
# 0                                                NaN
# 1  If you don't have a US cell phone, you can tex...
# 2  I am in a scenic part of Boston with a couple ...
# 3  Please be mindful of the property as it is old...
# 4  I have one roommate who lives on the lower lev...
#
#                                              transit  \
# 0  The bus stop is 2 blocks away, and frequent. B...
# 1  Plenty of safe street parking. Bus stops a few...
# 2  PUBLIC TRANSPORTATION: From the house, quick p...
# 3  There are buses that stop right in front of th...
# 4  From Logan Airport  and South Station you have...
#
#                                               access  \
# 0  You will have access to 2 bedrooms, a living r...
# 1  Apt has one more bedroom (which I use) and lar...
# 2  I am living in the apartment during your stay,...
# 3  The basement has a washer dryer and gym area. ...
# 4  You will have access to the front and side por...
#
#                                          interaction  \
# 0                                                NaN
# 1  If I am at home, I am likely working in my hom...
# 2  ABOUT ME: I'm a laid-back, friendly, unmarried...
# 3  We do live in the house therefore might be som...
# 4  I love my city and really enjoy sharing it wit...
#
#                                          house_rules  \
# 0  Clean up and treat the home the way you'd like...
# 1  Pet friendly but please confirm with me if the...
# 2  I encourage you to use my kitchen, cooking and...
# 3  - The bathroom and house are shared so please ...
# 4  Please no smoking in the house, porch or on th...
#
#                                        thumbnail_url  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...
# 1  https://a1.muscache.com/im/pictures/39327812/d...
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...
# 3  https://a2.muscache.com/im/pictures/39764190-1...
# 4  https://a1.muscache.com/im/pictures/97154760/8...
#
#                                           medium_url  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...
# 1  https://a1.muscache.com/im/pictures/39327812/d...
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...
# 3  https://a2.muscache.com/im/pictures/39764190-1...
# 4  https://a1.muscache.com/im/pictures/97154760/8...
#
#                                          picture_url  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...
# 1  https://a1.muscache.com/im/pictures/39327812/d...
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...
# 3  https://a2.muscache.com/im/pictures/39764190-1...
# 4  https://a1.muscache.com/im/pictures/97154760/8...
#
#                                       xl_picture_url   host_id  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...  31303940
# 1  https://a1.muscache.com/im/pictures/39327812/d...   2572247
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...     16701
# 3  https://a2.muscache.com/im/pictures/39764190-1...   6031442
# 4  https://a1.muscache.com/im/pictures/97154760/8...  15396970
#
#                                      host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/31303940  Virginia  2015-04-15
# 1   https://www.airbnb.com/users/show/2572247    Andrea  2012-06-07
# 2     https://www.airbnb.com/users/show/16701      Phil  2009-05-11
# 3   https://www.airbnb.com/users/show/6031442    Meghna  2013-04-21
# 4  https://www.airbnb.com/users/show/15396970     Linda  2014-05-11
#
#                           host_location  \
# 0  Boston, Massachusetts, United States
# 1  Boston, Massachusetts, United States
# 2  Boston, Massachusetts, United States
# 3  Boston, Massachusetts, United States
# 4  Boston, Massachusetts, United States
#
#                                           host_about  host_response_time  \
# 0  We are country and city connecting in our deck...                 NaN
# 1  I live in Boston and I like to travel and have...      within an hour
# 2  I am a middle-aged, single male with a wide ra...  within a few hours
# 3  My husband and I live on the property.  He’s a...  within a few hours
# 4  I work full time for a public school district....      within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                NaN                  NaN                 f
# 1               100%                 100%                 f
# 2               100%                  88%                 t
# 3               100%                  50%                 f
# 4               100%                 100%                 t
#
#                                   host_thumbnail_url  \
# 0  https://a2.muscache.com/im/pictures/5936fef0-b...
# 1  https://a2.muscache.com/im/users/2572247/profi...
# 2  https://a2.muscache.com/im/users/16701/profile...
# 3  https://a2.muscache.com/im/pictures/5d430cde-7...
# 4  https://a0.muscache.com/im/users/15396970/prof...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a2.muscache.com/im/pictures/5936fef0-b...         Roslindale
# 1  https://a2.muscache.com/im/users/2572247/profi...         Roslindale
# 2  https://a2.muscache.com/im/users/16701/profile...         Roslindale
# 3  https://a2.muscache.com/im/pictures/5d430cde-7...                NaN
# 4  https://a0.muscache.com/im/users/15396970/prof...         Roslindale
#
#    host_listings_count  host_total_listings_count  \
# 0                    1                          1
# 1                    1                          1
# 2                    1                          1
# 3                    1                          1
# 4                    1                          1
#
#                                   host_verifications host_has_profile_pic  \
# 0          ['email', 'phone', 'facebook', 'reviews']                    t
# 1  ['email', 'phone', 'facebook', 'linkedin', 'am...                    t
# 2             ['email', 'phone', 'reviews', 'jumio']                    t
# 3                      ['email', 'phone', 'reviews']                    t
# 4               ['email', 'phone', 'reviews', 'kba']                    t
#
#   host_identity_verified                                             street  \
# 0                      f      Birch Street, Boston, MA 02131, United States
# 1                      t  Pinehurst Street, Boston, MA 02131, United States
# 2                      t        Ardale St., Boston, MA 02131, United States
# 3                      f                          Boston, MA, United States
# 4                      t    Durnell Avenue, Boston, MA 02131, United States
#
#   neighbourhood neighbourhood_cleansed  neighbourhood_group_cleansed    city  \
# 0    Roslindale             Roslindale                           NaN  Boston
# 1    Roslindale             Roslindale                           NaN  Boston
# 2    Roslindale             Roslindale                           NaN  Boston
# 3           NaN             Roslindale                           NaN  Boston
# 4    Roslindale             Roslindale                           NaN  Boston
#
#   state zipcode  market smart_location country_code        country   latitude  \
# 0    MA   02131  Boston     Boston, MA           US  United States  42.282619
# 1    MA   02131  Boston     Boston, MA           US  United States  42.286241
# 2    MA   02131  Boston     Boston, MA           US  United States  42.292438
# 3    MA     NaN  Boston     Boston, MA           US  United States  42.281106
# 4    MA   02131  Boston     Boston, MA           US  United States  42.284512
#
#    longitude is_location_exact property_type        room_type  accommodates  \
# 0 -71.133068                 t         House  Entire home/apt             4
# 1 -71.134374                 t     Apartment     Private room             2
# 2 -71.135765                 t     Apartment     Private room             2
# 3 -71.121021                 f         House     Private room             4
# 4 -71.136258                 t         House     Private room             2
#
#    bathrooms  bedrooms  beds  bed_type  \
# 0        1.5       2.0   3.0  Real Bed
# 1        1.0       1.0   1.0  Real Bed
# 2        1.0       1.0   1.0  Real Bed
# 3        1.0       1.0   2.0  Real Bed
# 4        1.5       1.0   2.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,"Wireless Internet",Kitchen,"Free Parking ...          NaN  $250.00
# 1  {TV,Internet,"Wireless Internet","Air Conditio...          NaN   $65.00
# 2  {TV,"Cable TV","Wireless Internet","Air Condit...          NaN   $65.00
# 3  {TV,Internet,"Wireless Internet","Air Conditio...          NaN   $75.00
# 4  {Internet,"Wireless Internet","Air Conditionin...          NaN   $79.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN              NaN       $35.00                1
# 1      $400.00           NaN           $95.00       $10.00                0
# 2      $395.00     $1,350.00              NaN          NaN                1
# 3          NaN           NaN          $100.00       $50.00                2
# 4          NaN           NaN              NaN       $15.00                1
#
#   extra_people  minimum_nights  maximum_nights calendar_updated  \
# 0        $0.00               2            1125      2 weeks ago
# 1        $0.00               2              15       a week ago
# 2       $20.00               3              45       5 days ago
# 3       $25.00               1            1125       a week ago
# 4        $0.00               2              31      2 weeks ago
#
#    has_availability  availability_30  availability_60  availability_90  \
# 0               NaN                0                0                0
# 1               NaN               26               54               84
# 2               NaN               19               46               61
# 3               NaN                6               16               26
# 4               NaN               13               34               59
#
#    availability_365 calendar_last_scraped  number_of_reviews first_review  \
# 0                 0            2016-09-06                  0          NaN
# 1               359            2016-09-06                 36   2014-06-01
# 2               319            2016-09-06                 41   2009-07-19
# 3                98            2016-09-06                  1   2016-08-28
# 4               334            2016-09-06                 29   2015-08-18
#
#   last_review  review_scores_rating  review_scores_accuracy  \
# 0         NaN                   NaN                     NaN
# 1  2016-08-13                  94.0                    10.0
# 2  2016-08-05                  98.0                    10.0
# 3  2016-08-28                 100.0                    10.0
# 4  2016-09-01                  99.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        NaN                    NaN
# 1                        9.0                   10.0
# 2                        9.0                   10.0
# 3                       10.0                   10.0
# 4                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          NaN                     NaN                  NaN
# 1                         10.0                     9.0                  9.0
# 2                         10.0                     9.0                 10.0
# 3                         10.0                    10.0                 10.0
# 4                         10.0                     9.0                 10.0
#
#   requires_license  license  jurisdiction_names instant_bookable  \
# 0                f      NaN                 NaN                f
# 1                f      NaN                 NaN                t
# 2                f      NaN                 NaN                f
# 3                f      NaN                 NaN                f
# 4                f      NaN                 NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             t
# 3            moderate                             f
# 4            flexible                             f
#
#   require_guest_phone_verification  calculated_host_listings_count  \
# 0                                f                               1
# 1                                f                               1
# 2                                f                               1
# 3                                f                               1
# 4                                f                               1
#
#    reviews_per_month
# 0                NaN
# 1               1.30
# 2               0.47
# 3               1.00
# 4               2.25

# %%
print(calendar2017.shape)
print(listings.shape)
print(reviews.shape)
# Out:
# (1308890, 4)
# (3585, 95)
# (68275, 6)

# %%
# check out the missing values from 
print(np.sum(calendar2017.isnull()))

print('Portion of missing values in price column: {}'.format(calendar2017["price"].isnull().sum()/calendar2017.shape[0]))
# Out:
# listing_id         0
# date               0
# available          0
# price         665853
# dtype: int64
# Portion of missing values in price column: 0.5087157820748879

# %%
calendar2017.head()
# Out:
#    listing_id        date available price
# 0    12147973  2017-09-05         f   NaN
# 1    12147973  2017-09-04         f   NaN
# 2    12147973  2017-09-03         f   NaN
# 3    12147973  2017-09-02         f   NaN
# 4    12147973  2017-09-01         f   NaN

# %%
listings.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  \
# 0  Roslindale is quiet, convenient and friendly. ...
# 1  The room is in Roslindale, a diverse and prima...
# 2  The LOCATION: Roslindale is a safe and diverse...
# 3  Roslindale is a lovely little neighborhood loc...
# 4  I love the proximity to downtown, the neighbor...
#
#                                                notes  \
# 0                                                NaN
# 1  If you don't have a US cell phone, you can tex...
# 2  I am in a scenic part of Boston with a couple ...
# 3  Please be mindful of the property as it is old...
# 4  I have one roommate who lives on the lower lev...
#
#                                              transit  \
# 0  The bus stop is 2 blocks away, and frequent. B...
# 1  Plenty of safe street parking. Bus stops a few...
# 2  PUBLIC TRANSPORTATION: From the house, quick p...
# 3  There are buses that stop right in front of th...
# 4  From Logan Airport  and South Station you have...
#
#                                               access  \
# 0  You will have access to 2 bedrooms, a living r...
# 1  Apt has one more bedroom (which I use) and lar...
# 2  I am living in the apartment during your stay,...
# 3  The basement has a washer dryer and gym area. ...
# 4  You will have access to the front and side por...
#
#                                          interaction  \
# 0                                                NaN
# 1  If I am at home, I am likely working in my hom...
# 2  ABOUT ME: I'm a laid-back, friendly, unmarried...
# 3  We do live in the house therefore might be som...
# 4  I love my city and really enjoy sharing it wit...
#
#                                          house_rules  \
# 0  Clean up and treat the home the way you'd like...
# 1  Pet friendly but please confirm with me if the...
# 2  I encourage you to use my kitchen, cooking and...
# 3  - The bathroom and house are shared so please ...
# 4  Please no smoking in the house, porch or on th...
#
#                                        thumbnail_url  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...
# 1  https://a1.muscache.com/im/pictures/39327812/d...
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...
# 3  https://a2.muscache.com/im/pictures/39764190-1...
# 4  https://a1.muscache.com/im/pictures/97154760/8...
#
#                                           medium_url  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...
# 1  https://a1.muscache.com/im/pictures/39327812/d...
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...
# 3  https://a2.muscache.com/im/pictures/39764190-1...
# 4  https://a1.muscache.com/im/pictures/97154760/8...
#
#                                          picture_url  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...
# 1  https://a1.muscache.com/im/pictures/39327812/d...
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...
# 3  https://a2.muscache.com/im/pictures/39764190-1...
# 4  https://a1.muscache.com/im/pictures/97154760/8...
#
#                                       xl_picture_url   host_id  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...  31303940
# 1  https://a1.muscache.com/im/pictures/39327812/d...   2572247
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...     16701
# 3  https://a2.muscache.com/im/pictures/39764190-1...   6031442
# 4  https://a1.muscache.com/im/pictures/97154760/8...  15396970
#
#                                      host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/31303940  Virginia  2015-04-15
# 1   https://www.airbnb.com/users/show/2572247    Andrea  2012-06-07
# 2     https://www.airbnb.com/users/show/16701      Phil  2009-05-11
# 3   https://www.airbnb.com/users/show/6031442    Meghna  2013-04-21
# 4  https://www.airbnb.com/users/show/15396970     Linda  2014-05-11
#
#                           host_location  \
# 0  Boston, Massachusetts, United States
# 1  Boston, Massachusetts, United States
# 2  Boston, Massachusetts, United States
# 3  Boston, Massachusetts, United States
# 4  Boston, Massachusetts, United States
#
#                                           host_about  host_response_time  \
# 0  We are country and city connecting in our deck...                 NaN
# 1  I live in Boston and I like to travel and have...      within an hour
# 2  I am a middle-aged, single male with a wide ra...  within a few hours
# 3  My husband and I live on the property.  He’s a...  within a few hours
# 4  I work full time for a public school district....      within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                NaN                  NaN                 f
# 1               100%                 100%                 f
# 2               100%                  88%                 t
# 3               100%                  50%                 f
# 4               100%                 100%                 t
#
#                                   host_thumbnail_url  \
# 0  https://a2.muscache.com/im/pictures/5936fef0-b...
# 1  https://a2.muscache.com/im/users/2572247/profi...
# 2  https://a2.muscache.com/im/users/16701/profile...
# 3  https://a2.muscache.com/im/pictures/5d430cde-7...
# 4  https://a0.muscache.com/im/users/15396970/prof...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a2.muscache.com/im/pictures/5936fef0-b...         Roslindale
# 1  https://a2.muscache.com/im/users/2572247/profi...         Roslindale
# 2  https://a2.muscache.com/im/users/16701/profile...         Roslindale
# 3  https://a2.muscache.com/im/pictures/5d430cde-7...                NaN
# 4  https://a0.muscache.com/im/users/15396970/prof...         Roslindale
#
#    host_listings_count  host_total_listings_count  \
# 0                    1                          1
# 1                    1                          1
# 2                    1                          1
# 3                    1                          1
# 4                    1                          1
#
#                                   host_verifications host_has_profile_pic  \
# 0          ['email', 'phone', 'facebook', 'reviews']                    t
# 1  ['email', 'phone', 'facebook', 'linkedin', 'am...                    t
# 2             ['email', 'phone', 'reviews', 'jumio']                    t
# 3                      ['email', 'phone', 'reviews']                    t
# 4               ['email', 'phone', 'reviews', 'kba']                    t
#
#   host_identity_verified                                             street  \
# 0                      f      Birch Street, Boston, MA 02131, United States
# 1                      t  Pinehurst Street, Boston, MA 02131, United States
# 2                      t        Ardale St., Boston, MA 02131, United States
# 3                      f                          Boston, MA, United States
# 4                      t    Durnell Avenue, Boston, MA 02131, United States
#
#   neighbourhood neighbourhood_cleansed  neighbourhood_group_cleansed    city  \
# 0    Roslindale             Roslindale                           NaN  Boston
# 1    Roslindale             Roslindale                           NaN  Boston
# 2    Roslindale             Roslindale                           NaN  Boston
# 3           NaN             Roslindale                           NaN  Boston
# 4    Roslindale             Roslindale                           NaN  Boston
#
#   state zipcode  market smart_location country_code        country   latitude  \
# 0    MA   02131  Boston     Boston, MA           US  United States  42.282619
# 1    MA   02131  Boston     Boston, MA           US  United States  42.286241
# 2    MA   02131  Boston     Boston, MA           US  United States  42.292438
# 3    MA     NaN  Boston     Boston, MA           US  United States  42.281106
# 4    MA   02131  Boston     Boston, MA           US  United States  42.284512
#
#    longitude is_location_exact property_type        room_type  accommodates  \
# 0 -71.133068                 t         House  Entire home/apt             4
# 1 -71.134374                 t     Apartment     Private room             2
# 2 -71.135765                 t     Apartment     Private room             2
# 3 -71.121021                 f         House     Private room             4
# 4 -71.136258                 t         House     Private room             2
#
#    bathrooms  bedrooms  beds  bed_type  \
# 0        1.5       2.0   3.0  Real Bed
# 1        1.0       1.0   1.0  Real Bed
# 2        1.0       1.0   1.0  Real Bed
# 3        1.0       1.0   2.0  Real Bed
# 4        1.5       1.0   2.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,"Wireless Internet",Kitchen,"Free Parking ...          NaN  $250.00
# 1  {TV,Internet,"Wireless Internet","Air Conditio...          NaN   $65.00
# 2  {TV,"Cable TV","Wireless Internet","Air Condit...          NaN   $65.00
# 3  {TV,Internet,"Wireless Internet","Air Conditio...          NaN   $75.00
# 4  {Internet,"Wireless Internet","Air Conditionin...          NaN   $79.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN              NaN       $35.00                1
# 1      $400.00           NaN           $95.00       $10.00                0
# 2      $395.00     $1,350.00              NaN          NaN                1
# 3          NaN           NaN          $100.00       $50.00                2
# 4          NaN           NaN              NaN       $15.00                1
#
#   extra_people  minimum_nights  maximum_nights calendar_updated  \
# 0        $0.00               2            1125      2 weeks ago
# 1        $0.00               2              15       a week ago
# 2       $20.00               3              45       5 days ago
# 3       $25.00               1            1125       a week ago
# 4        $0.00               2              31      2 weeks ago
#
#    has_availability  availability_30  availability_60  availability_90  \
# 0               NaN                0                0                0
# 1               NaN               26               54               84
# 2               NaN               19               46               61
# 3               NaN                6               16               26
# 4               NaN               13               34               59
#
#    availability_365 calendar_last_scraped  number_of_reviews first_review  \
# 0                 0            2016-09-06                  0          NaN
# 1               359            2016-09-06                 36   2014-06-01
# 2               319            2016-09-06                 41   2009-07-19
# 3                98            2016-09-06                  1   2016-08-28
# 4               334            2016-09-06                 29   2015-08-18
#
#   last_review  review_scores_rating  review_scores_accuracy  \
# 0         NaN                   NaN                     NaN
# 1  2016-08-13                  94.0                    10.0
# 2  2016-08-05                  98.0                    10.0
# 3  2016-08-28                 100.0                    10.0
# 4  2016-09-01                  99.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        NaN                    NaN
# 1                        9.0                   10.0
# 2                        9.0                   10.0
# 3                       10.0                   10.0
# 4                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                          NaN                     NaN                  NaN
# 1                         10.0                     9.0                  9.0
# 2                         10.0                     9.0                 10.0
# 3                         10.0                    10.0                 10.0
# 4                         10.0                     9.0                 10.0
#
#   requires_license  license  jurisdiction_names instant_bookable  \
# 0                f      NaN                 NaN                f
# 1                f      NaN                 NaN                t
# 2                f      NaN                 NaN                f
# 3                f      NaN                 NaN                f
# 4                f      NaN                 NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             t
# 3            moderate                             f
# 4            flexible                             f
#
#   require_guest_phone_verification  calculated_host_listings_count  \
# 0                                f                               1
# 1                                f                               1
# 2                                f                               1
# 3                                f                               1
# 4                                f                               1
#
#    reviews_per_month
# 0                NaN
# 1               1.30
# 2               0.47
# 3               1.00
# 4               2.25

# %% [markdown]
# ## What times of the year are especially expensive?

# %%
# clean the price column to allow for arithmetic operations
conv_str = lambda x: str(x)[1:].replace(',', '') if '$' in str(x) else x

calendar2017['price'] = calendar2017['price'].apply(conv_str)
calendar2017['price'] = calendar2017['price'].apply(lambda x: float(x))
calendar2017.head()
# Out:
#    listing_id        date available  price
# 0    12147973  2017-09-05         f    NaN
# 1    12147973  2017-09-04         f    NaN
# 2    12147973  2017-09-03         f    NaN
# 3    12147973  2017-09-02         f    NaN
# 4    12147973  2017-09-01         f    NaN

# %%
# get the descriptive statistics of average price per listing
grouped_price = calendar2017.groupby('listing_id')['price'].mean()

grouped_price.describe()
# Out:
# count    2906.000000
# mean      196.935127
# std       157.729807
# min        11.000000
# 25%        90.000000
# 50%       160.000000
# 75%       264.717664
# max      4000.000000
# Name: price, dtype: float64

# %%
# plot the average prices across all listing ids
plt.figure(figsize=(15,6))
plt.hist(grouped_price, bins=100);
# Out:
# C:\Users\julia\Anaconda3\lib\site-packages\numpy\lib\histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\julia\Anaconda3\lib\site-packages\numpy\lib\histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# average price throughout time
grouped_date = calendar2017.groupby('date')['price'].mean()

grouped_date.describe()
# Out:
# count    365.000000
# mean     201.165200
# std       20.989130
# min      177.023002
# 25%      186.764936
# 50%      196.100469
# 75%      205.207474
# max      286.921977
# Name: price, dtype: float64

# %%
grouped_date
# Out:
# date
# 2016-09-06    241.043860
# 2016-09-07    251.833691
# 2016-09-08    251.748749
# 2016-09-09    261.859327
# 2016-09-10    266.847280
# 2016-09-11    249.565041
# 2016-09-12    245.732597
# 2016-09-13    250.206977
# 2016-09-14    256.647799
# 2016-09-15    269.092903
# 2016-09-16    286.921977
# 2016-09-17    286.185554
# 2016-09-18    261.592955
# 2016-09-19    246.632945
# 2016-09-20    241.203993
# 2016-09-21    244.225750
# 2016-09-22    249.625355
# 2016-09-23    250.712274
# 2016-09-24    259.378705
# 2016-09-25    256.321691
# 2016-09-26    244.979556
# 2016-09-27    245.324846
# 2016-09-28    234.278376
# 2016-09-29    243.275229
# 2016-09-30    246.097490
# 2016-10-01    245.459259
# 2016-10-02    236.312305
# 2016-10-03    230.048227
# 2016-10-04    228.680249
# 2016-10-05    229.066098
#                  ...
# 2017-08-07    200.423529
# 2017-08-08    200.494684
# 2017-08-09    201.649692
# 2017-08-10    201.793509
# 2017-08-11    208.539665
# 2017-08-12    204.606484
# 2017-08-13    199.385818
# 2017-08-14    196.306145
# 2017-08-15    197.558906
# 2017-08-16    198.872138
# 2017-08-17    205.207474
# 2017-08-18    209.418708
# 2017-08-19    209.739009
# 2017-08-20    205.332962
# 2017-08-21    203.910963
# 2017-08-22    204.514730
# 2017-08-23    203.418101
# 2017-08-24    205.480289
# 2017-08-25    207.857301
# 2017-08-26    212.498612
# 2017-08-27    203.397550
# 2017-08-28    200.863991
# 2017-08-29    198.023942
# 2017-08-30    193.548747
# 2017-08-31    200.543684
# 2017-09-01    202.046797
# 2017-09-02    197.997775
# 2017-09-03    192.566038
# 2017-09-04    189.907829
# 2017-09-05    190.804553
# Name: price, Length: 365, dtype: float64

# %%
# plot the average prices across all dates
index_date = [np.datetime64(x) for x in grouped_date.index]

fig, ax = plt.subplots(figsize=(15,6))

plt.scatter(index_date, grouped_date.values)
plt.xlabel('Date')
plt.ylabel('Average Price')
#ax.set_ylim([100,500])
plt.title('Average price on date throughout 2016/2017')
plt.xticks(rotation=30);

# %%
# cleaning function
def clean(df, to_be_cleaned, string_remov):
    '''
    cleaning a column in a dataframe of a specified string
    INPUT: df = dataframe, to_be_cleaned = name of column that needs to be cleaned, string_remov = string in column that should be replaced
    OUTPUT: changed dataframe
    '''
    # cleaning price column
    conv_str = lambda x: str(x)[1:].replace(',', '') if string_remov in str(x) else x
    df[to_be_cleaned] = df[to_be_cleaned].apply(conv_str)
    df[to_be_cleaned] = df[to_be_cleaned].apply(lambda x: float(x))
    
    return df

# %%
def format_plot(df):
    '''
    formatting a column in a dataframe for a plot function
    INPUT: dataframe
    OUTPUT: Series with average price throughout time; Series with dates in np.datetime64 format
    '''
    # average price throughout time
    grouped_date = df.groupby('date')['price'].mean()
    
    # remove year from date column to allow to lay each calendar dataframe price column on top of each other
    index_date = [x[5:] for x in grouped_date.index]

    return index_date, grouped_date

# %%
# plotting the price data of relevant calendar dataframes
def plot_cal(x_lst, y_lst, year_lst, color_lst):
    '''
    This function returns a scatterplot with average price data from multiple years layed ontop of each other
    INPUT: index_date is x_lst, grouped_date is y_lst
    OUTPUT: scatterplot of all average prices of calendar dataframes over time
    '''
    # plot data
    fig, ax = plt.subplots(figsize=(15,6))
    
    for i in range(len(x_lst)):
        ax.scatter(x_lst[i], y_lst[i].values, c=color_lst[i], label=year_lst[i])
    
    plt.xlabel('Date')
    plt.ylabel('Average Price')
    ax.set_ylim([100,500])
    monthyearFmt = mdates.DateFormatter('%B')
    ax.xaxis.set_major_formatter(monthyearFmt)
    plt.legend(loc='upper left')
    plt.title('Average prices throughout the year');
    #plt.xticks(rotation=30);

# %%
# clean all calendar price columns
X2017, y2017 = format_plot(clean(calendar2017, 'price', '$'))
X2018, y2018 = format_plot(clean(calendar2018, 'price', '$'))
X2019, y2019 = format_plot(clean(calendar2019, 'price', '$'))

# %%
# format date column to datetime format, removing the year to later allow for overlapping plotting based on day and month
X2017 = [datetime.strptime(x, '%m-%d') for x in X2017]
X2018 = [datetime.strptime(x, '%m-%d') for x in X2018]
X2019 = [datetime.strptime(x, '%m-%d') for x in X2019]

# %%
# creating input lists for plot function
x_lst = [X2017, X2018, X2019]
y_lst = [y2017, y2018, y2019]
year_lst = ['2017', '2018', '2019']
color_lst = ['b', 'r', 'g', 'y', 'm']

# %%
# plotting all three calendars' average prices
plot_cal(x_lst, y_lst, year_lst, color_lst)

# %%
# check whether any listings dropped out during the course of the year
grouped_ids = calendar2017.groupby('date')['listing_id'].count()

grouped_ids.describe()
# Out:
# count     365.0
# mean     3586.0
# std         0.0
# min      3586.0
# 25%      3586.0
# 50%      3586.0
# 75%      3586.0
# max      3586.0
# Name: listing_id, dtype: float64

# %% [markdown]
# ## Does a higher price indicate that the flat is cleaner?
#
# Let's look at our next question.

# %%
listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')

# %%
reviews.columns
# Out:
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments'], dtype='object')

# %%
# get an overview of the review_scores_cleanliness feature
listings['review_scores_cleanliness'].describe()
# Out:
# count    2767.000000
# mean        9.258041
# std         1.168977
# min         2.000000
# 25%         9.000000
# 50%        10.000000
# 75%        10.000000
# max        10.000000
# Name: review_scores_cleanliness, dtype: float64

# %%
price_per_id = pd.DataFrame(calendar2017.groupby('listing_id')['price'].mean())

price_per_id['listing_id'] = price_per_id.index

price_per_id.index.names = ['id']

new_price = price_per_id.reset_index(drop=True)

new_price
# Out:
#            price  listing_id
# 0      35.204819        3353
# 1     147.267442        5506
# 2     197.407407        6695
# 3      65.000000        6976
# 4     154.000000        8792
# 5     225.000000        9273
# 6     236.856354        9765
# 7     222.321981        9824
# 8     266.554945        9855
# 9     363.394813        9857
# 10    486.774725        9858
# 11    269.759207        9860
# 12    288.776243        9870
# 13    256.554945        9903
# 14    150.000000       10730
# 15    116.395349       10758
# 16     80.802469       10807
# 17    110.116279       10809
# 18    251.744186       10810
# 19    165.520548       10811
# 20    200.000000       12356
# 21    418.354098       12441
# 22    400.837838       13059
# 23    451.097403       13589
# 24    377.994350       13592
# 25    169.890208       18711
# 26     75.000000       20000
# 27    329.000000       21337
# 28    356.554945       21891
# 29    233.988796       22208
# ...          ...         ...
# 3555   70.700000    14874204
# 3556  110.710526    14878512
# 3557  179.000000    14881840
# 3558   60.000000    14884243
# 3559  264.562963    14885592
# 3560   95.644172    14885796
# 3561   56.839286    14885917
# 3562  249.000000    14887382
# 3563  424.011461    14897219
# 3564  309.000000    14897997
# 3565  180.255474    14898146
# 3566   91.383754    14898198
# 3567   80.000000    14900236
# 3568  132.769886    14902894
# 3569  189.405099    14907062
# 3570  219.206154    14908177
# 3571  314.971264    14909417
# 3572  248.397590    14912536
# 3573  127.074286    14916248
# 3574  170.000000    14917151
# 3575  250.000000    14917833
# 3576  359.000000    14918032
# 3577  100.000000    14918194
# 3578  160.000000    14918425
# 3579   60.854795    14918869
# 3580  169.515152    14924831
# 3581   55.000000    14928000
# 3582  105.380531    14928333
# 3583   49.000000    14933380
# 3584  165.113333    14933461
#
# [3585 rows x 2 columns]

# %%
cleanliness = pd.DataFrame(listings[['id', 'review_scores_cleanliness']])

cleanliness = cleanliness.rename(index=str, columns={'id': 'listing_id'})

cleanliness
# Out:
#       listing_id  review_scores_cleanliness
# 0       12147973                        NaN
# 1        3075044                        9.0
# 2           6976                        9.0
# 3        1436513                       10.0
# 4        7651065                       10.0
# 5       12386020                       10.0
# 6        5706985                       10.0
# 7        2843445                       10.0
# 8         753446                       10.0
# 9         849408                        9.0
# 10      12023024                        8.0
# 11       1668313                       10.0
# 12       2684840                       10.0
# 13      13547301                       10.0
# 14       5434353                        9.0
# 15        225979                       10.0
# 16       3420384                       10.0
# 17      13512930                       10.0
# 18       7482195                        NaN
# 19       7252607                       10.0
# 20       2583074                       10.0
# 21      13251243                       10.0
# 22        225834                       10.0
# 23       6400432                        9.0
# 24       5498472                       10.0
# 25        894539                       10.0
# 26        879929                        9.0
# 27       9218312                       10.0
# 28        321328                        8.0
# 29       1810172                        9.0
# ...          ...                        ...
# 3555    13015653                       10.0
# 3556    14849141                        NaN
# 3557    14604429                        NaN
# 3558    14592644                        NaN
# 3559    12915510                       10.0
# 3560    14887382                        NaN
# 3561    14823430                        NaN
# 3562    14881840                        NaN
# 3563    11452297                        NaN
# 3564    14576706                        NaN
# 3565    14335003                        8.0
# 3566    14871445                        NaN
# 3567    14472678                        NaN
# 3568    14574800                        8.0
# 3569    14426586                        NaN
# 3570     3131519                        9.0
# 3571    14592547                       10.0
# 3572    14744740                        NaN
# 3573    14504583                       10.0
# 3574    14743129                        8.0
# 3575     5280827                        7.0
# 3576    14689681                        NaN
# 3577    13750763                        NaN
# 3578    14536322                       10.0
# 3579    14852179                        NaN
# 3580     8373729                       10.0
# 3581    14844274                        NaN
# 3582    14585486                        NaN
# 3583    14603878                        8.0
# 3584    14504422                        NaN
#
# [3585 rows x 2 columns]

# %%
clean_price = pd.merge(cleanliness, price_per_id, on='listing_id', how='outer')

# %%
np.sum(clean_price.isnull())
# Out:
# listing_id                     0
# review_scores_cleanliness    818
# price                        679
# dtype: int64

# %%
clean_price = clean_price.dropna(axis=0, how='any')

# %%
np.sum(clean_price.isnull())
# Out:
# listing_id                   0
# review_scores_cleanliness    0
# price                        0
# dtype: int64

# %%
plt.scatter(clean_price['review_scores_cleanliness'], clean_price['price'], c='y', alpha=0.25);

# %%
corr, p = pearsonr(clean_price['review_scores_cleanliness'], clean_price['price'])
print(corr)
print(p)
# Out:
# 0.11144494613748308
# 6.196438959803245e-08

# %% [markdown]
# ## Do some neighborhoods have particularly high ratings?

# %%
listings.groupby('neighbourhood_cleansed')['review_scores_rating'].mean()
# Out:
# neighbourhood_cleansed
# Allston                    90.164835
# Back Bay                   91.531646
# Bay Village                93.000000
# Beacon Hill                93.378698
# Brighton                   90.864662
# Charlestown                93.697368
# Chinatown                  92.121951
# Dorchester                 89.280000
# Downtown                   92.432203
# East Boston                90.272059
# Fenway                     89.417112
# Hyde Park                  92.280000
# Jamaica Plain              94.159322
# Leather District           98.333333
# Longwood Medical Area      94.000000
# Mattapan                   91.000000
# Mission Hill               87.695122
# North End                  93.725000
# Roslindale                 95.380000
# Roxbury                    89.803419
# South Boston               93.980392
# South Boston Waterfront    94.431034
# South End                  93.264925
# West End                   90.333333
# West Roxbury               95.212121
# Name: review_scores_rating, dtype: float64

# %% [markdown]
# ## Which are the best neighborhoods to stay in?

# %%
# how many values are missing in neighborhood_overview
np.sum(listings.isnull())['neighborhood_overview']

listings_neigh = listings.dropna(axis=0, subset=['neighborhood_overview'], how='any')

np.sum(listings_neigh.isnull())['neighborhood_overview']
# Out:
# 0

# %%
# create new dataframe that shows grouped reviews by neighborhood
neigh_ov = pd.DataFrame(listings_neigh.groupby('neighbourhood_cleansed')['neighborhood_overview'].apply(str))

neigh_ov['neighborhood'] = neigh_ov.index

neigh_ov = neigh_ov.reset_index(drop=True)

# %%
# check whether there are missing values in this data frame
np.sum(neigh_ov.isnull())
# Out:
# neighborhood_overview    0
# neighborhood             0
# dtype: int64

# %%
# function to create wordclouds
def word_cloud(df, column, feature, stop_words):
    '''
    plotting word clouds based on different dataframes, columns, features and words to exclude
    INPUT: df = dataframe, column = the column that the text is grouped by, feature = the text to be plotted, stop_words = all words to be excluded from the wordcloud
    OUTPUT: wordcloud plots
    '''
    count = 0
    
    for item in df[column]:
    
        text_cont = df[df[column] == item][feature][count]
        wordcloud = WordCloud(stopwords=stop_words, random_state=42).generate(text_cont)
        count += 1

        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis('off')
        plt.title(item)
        plt.show()

# %%
# create word cloud for the neighborhood descriptions
neighborhoods = set([x.lower() for x in neigh_ov['neighborhood']])
sum_stop = neighborhoods.union(set(('ha', 'back', 'bay', '...', 'jamaica', 'plain', 'apartment', 'boston', 'neighborhood', 'located', 'location')))
stop_words = STOPWORDS.union(sum_stop)

word_cloud(neigh_ov, 'neighborhood', 'neighborhood_overview', stop_words)

# %%
# function to get the most common words of a string
def most_com(df, column, feature, name, stop_words, top_k=15):
    '''
    return the most common words of a string
    INPUT: df = dataframe, column = groupby column, feature = feature in dataframe with text to be analyzed, 
           name = name of certain return of groupby column, stop_words = words to disregard, 
           top_k = top most common words (default is 15)
    OUTPUT: list of tuples with word and count of word
    '''
    text = df[df[column] == name][feature][df.loc[df[column] == name].index[0]]
    text = re.findall(r"[\w']+", text)
    text = [word.lower() if word[-1] != 's' else word[:-1].lower() for word in text]

    most_com = Counter(word for word in text if word not in stop_words).most_common(top_k)
    
    return most_com

# %%
# dictionary with top 15 most common words for all neighborhoods
top_all = defaultdict()
for item in neigh_ov['neighborhood']:
    top_all[item] = most_com(neigh_ov, 'neighborhood', 'neighborhood_overview', item, stop_words)

# %%
# creating dictionaries with information on quiet, safe, residential, family-friendly neighborhoods
# creating dictionaries with information on vibrant, eclectic neighborhoods with attractions
name_quiet = ['quiet', 'safe', 'family', 'friendly', 'residential']
name_vibe = ['vibrant', 'eclectic', 'attraction', 'restaurant', 'vibe', 'theater' ,'hip', 'center']

def dict_quiet_vibe(name, pos_neg_sign):
    temp_dicts = []
    for item in name:
        sum_most = defaultdict()
        for k, v in top_all.items():
            
            sum_most[k] = [(num[1]/v[0][1])*pos_neg_sign for num in v if item in num]
        temp_dicts.append(sum_most)
    return temp_dicts


quiet_dicts = dict_quiet_vibe(name_quiet, 1)
vibe_dicts = dict_quiet_vibe(name_vibe, -1)

vibe_dicts
# Out:
# [defaultdict(None,
#              {'Allston': [],
#               'Back Bay': [],
#               'Bay Village': [],
#               'Beacon Hill': [],
#               'Brighton': [],
#               'Charlestown': [],
#               'Chinatown': [],
#               'Dorchester': [],
#               'Downtown': [],
#               'East Boston': [],
#               'Fenway': [],
#               'Hyde Park': [],
#               'Jamaica Plain': [-0.5],
#               'Leather District': [],
#               'Longwood Medical Area': [],
#               'Mattapan': [],
#               'Mission Hill': [],
#               'North End': [],
#               'Roslindale': [],
#               'Roxbury': [],
#               'South Boston': [],
#               'South Boston Waterfront': [],
#               'South End': [],
#               'West End': [],
#               'West Roxbury': []}),
#  defaultdict(None,
#              {'Allston': [],
#               'Back Bay': [],
#               'Bay Village': [],
#               'Beacon Hill': [],
#               'Brighton': [],
#               'Charlestown': [],
#               'Chinatown': [],
#               'Dorchester': [],
#               'Downtown': [],
#               'East Boston': [],
#               'Fenway': [],
#               'Hyde Park': [],
#               'Jamaica Plain': [-0.375],
#               'Leather District': [],
#               'Longwood Medical Area': [],
#               'Mattapan': [],
#               'Mission Hill': [],
#               'North End': [],
#               'Roslindale': [],
#               'Roxbury': [],
#               'South Boston': [],
#               'South Boston Waterfront': [],
#               'South End': [],
#               'West End': [],
#               'West Roxbury': []}),
#  defaultdict(None,
#              {'Allston': [],
#               'Back Bay': [],
#               'Bay Village': [],
#               'Beacon Hill': [],
#               'Brighton': [],
#               'Charlestown': [],
#               'Chinatown': [-1.0],
#               'Dorchester': [],
#               'Downtown': [-1.0],
#               'East Boston': [],
#               'Fenway': [],
#               'Hyde Park': [],
#               'Jamaica Plain': [],
#               'Leather District': [],
#               'Longwood Medical Area': [],
#               'Mattapan': [],
#               'Mission Hill': [-0.7272727272727273],
#               'North End': [],
#               'Roslindale': [],
#               'Roxbury': [],
#               'South Boston': [],
#               'South Boston Waterfront': [],
#               'South End': [],
#               'West End': [-0.38461538461538464],
#               'West Roxbury': []}),
#  defaultdict(None,
#              {'Allston': [-0.3076923076923077],
#               'Back Bay': [],
#               'Bay Village': [],
#               'Beacon Hill': [],
#               'Brighton': [],
#               'Charlestown': [],
#               'Chinatown': [-0.6086956521739131],
#               'Dorchester': [],
#               'Downtown': [],
#               'East Boston': [],
#               'Fenway': [],
#               'Hyde Park': [],
#               'Jamaica Plain': [],
#               'Leather District': [],
#               'Longwood Medical Area': [],
#               'Mattapan': [],
#               'Mission Hill': [-1.0],
#               'North End': [-0.1875],
#               'Roslindale': [],
#               'Roxbury': [],
#               'South Boston': [],
#               'South Boston Waterfront': [-0.5555555555555556],
#               'South End': [-0.13043478260869565],
#               'West End': [],
#               'West Roxbury': [-0.2222222222222222]}),
#  defaultdict(None,
#              {'Allston': [-0.23076923076923078],
#               'Back Bay': [],
#               'Bay Village': [],
#               'Beacon Hill': [],
#               'Brighton': [],
#               'Charlestown': [],
#               'Chinatown': [],
#               'Dorchester': [],
#               'Downtown': [],
#               'East Boston': [],
#               'Fenway': [],
#               'Hyde Park': [],
#               'Jamaica Plain': [-0.5],
#               'Leather District': [],
#               'Longwood Medical Area': [],
#               'Mattapan': [],
#               'Mission Hill': [],
#               'North End': [],
#               'Roslindale': [],
#               'Roxbury': [],
#               'South Boston': [],
#               'South Boston Waterfront': [],
#               'South End': [],
#               'West End': [],
#               'West Roxbury': []}),
#  defaultdict(None,
#              {'Allston': [],
#               'Back Bay': [],
#               'Bay Village': [],
#               'Beacon Hill': [],
#               'Brighton': [],
#               'Charlestown': [],
#               'Chinatown': [],
#               'Dorchester': [],
#               'Downtown': [-0.4166666666666667],
#               'East Boston': [],
#               'Fenway': [],
#               'Hyde Park': [],
#               'Jamaica Plain': [],
#               'Leather District': [],
#               'Longwood Medical Area': [],
#               'Mattapan': [],
#               'Mission Hill': [],
#               'North End': [],
#               'Roslindale': [],
#               'Roxbury': [],
#               'South Boston': [],
#               'South Boston Waterfront': [],
#               'South End': [],
#               'West End': [],
#               'West Roxbury': []}),
#  defaultdict(None,
#              {'Allston': [],
#               'Back Bay': [],
#               'Bay Village': [],
#               'Beacon Hill': [],
#               'Brighton': [],
#               'Charlestown': [],
#               'Chinatown': [],
#               'Dorchester': [],
#               'Downtown': [],
#               'East Boston': [],
#               'Fenway': [],
#               'Hyde Park': [],
#               'Jamaica Plain': [-0.375],
#               'Leather District': [],
#               'Longwood Medical Area': [],
#               'Mattapan': [],
#               'Mission Hill': [],
#               'North End': [],
#               'Roslindale': [-0.3],
#               'Roxbury': [],
#               'South Boston': [],
#               'South Boston Waterfront': [],
#               'South End': [],
#               'West End': [],
#               'West Roxbury': []}),
#  defaultdict(None,
#              {'Allston': [],
#               'Back Bay': [],
#               'Bay Village': [],
#               'Beacon Hill': [],
#               'Brighton': [],
#               'Charlestown': [],
#               'Chinatown': [],
#               'Dorchester': [],
#               'Downtown': [],
#               'East Boston': [-0.2777777777777778],
#               'Fenway': [],
#               'Hyde Park': [],
#               'Jamaica Plain': [],
#               'Leather District': [-1.0],
#               'Longwood Medical Area': [],
#               'Mattapan': [],
#               'Mission Hill': [],
#               'North End': [],
#               'Roslindale': [],
#               'Roxbury': [],
#               'South Boston': [],
#               'South Boston Waterfront': [],
#               'South End': [],
#               'West End': [-1.0],
#               'West Roxbury': []})]

# %%
# function to convert dicts to dataframes, clean and merge them
def dict_to_df(dict_conv, name):
    '''
    converting dict to dataframe, rearranging and renaming the columns and imputing NaNs
    INPUT: dict = dictionary to be converted, name = name of the newly added column
    OUTPUT: dataframe
    '''
    count = 0
    sum_df = pd.DataFrame()
    for diction in dict_conv:
        temp_df = pd.DataFrame.from_dict(diction, orient='index')
        temp_df.fillna(0, inplace=True)
        temp_df['neighborhood'] = temp_df.index

        temp_df = temp_df.reset_index(drop=True)
        temp_df = temp_df.rename(index=str, columns={0: name[count]})
        
        if count == 0:
            sum_df = temp_df
        else:
            sum_df = pd.merge(sum_df, temp_df, on='neighborhood', how='outer')
        count += 1
        
    return sum_df

# %%
# convert the dictionaries into dataframes and merge the two, then summarize and normalize the data to prepare for plotting
quiet_vac = dict_to_df(quiet_dicts, name_quiet)
vibe_vac = dict_to_df(vibe_dicts, name_vibe)
type_vac = pd.merge(quiet_vac, vibe_vac, on='neighborhood', how='outer')

total_names = []
total_names.extend(name_vibe)
total_names.extend(name_quiet)

type_vac['sum'] = type_vac[total_names].sum(axis=1)
type_vac['normalized'] = type_vac['sum'].apply(lambda x: (x - np.mean(type_vac['sum']))/np.std(type_vac['sum']))

type_vac['colors'] = ['red' if x < 0 else 'green' for x in type_vac['normalized']]
type_vac.sort_values('normalized', inplace=True)
type_vac = type_vac.reset_index(drop=True)
type_vac = type_vac[['neighborhood', 'quiet', 'safe', 'family', 'friendly', 'residential', 'vibrant', 'eclectic', 'attraction', 'restaurant', 'vibe', 'theater' ,'hip', 'center', 'sum', 'normalized', 'colors']]

type_vac
# Out:
#                neighborhood     quiet      safe  family  friendly  \
# 0                 Chinatown  0.000000  0.000000     0.0  0.000000
# 1                  Downtown  0.000000  0.000000     0.0  0.000000
# 2                  West End  0.000000  0.000000     0.0  0.000000
# 3             Jamaica Plain  0.000000  0.375000     0.0  0.000000
# 4              Mission Hill  0.000000  0.363636     0.0  0.000000
# 5          Leather District  0.000000  0.000000     0.0  0.000000
# 6   South Boston Waterfront  0.000000  0.000000     0.0  0.000000
# 7                 North End  0.000000  0.000000     0.0  0.000000
# 8                 South End  0.000000  0.000000     0.0  0.000000
# 9               East Boston  0.000000  0.222222     0.0  0.000000
# 10                   Fenway  0.000000  0.000000     0.0  0.000000
# 11                 Back Bay  0.000000  0.000000     0.0  0.000000
# 12    Longwood Medical Area  0.000000  0.000000     0.0  0.000000
# 13              Beacon Hill  0.233333  0.000000     0.0  0.000000
# 14                  Roxbury  0.562500  0.000000     0.0  0.000000
# 15              Bay Village  0.571429  0.000000     0.0  0.000000
# 16             South Boston  0.500000  0.500000     0.0  0.000000
# 17              Charlestown  0.833333  0.333333     0.0  0.000000
# 18             West Roxbury  1.000000  0.222222     0.0  0.444444
# 19               Roslindale  1.000000  0.300000     0.4  0.300000
# 20                 Mattapan  0.800000  0.000000     0.0  0.000000
# 21                  Allston  1.000000  1.000000     0.0  0.000000
# 22               Dorchester  0.875000  0.750000     0.0  0.000000
# 23                Hyde Park  1.000000  0.333333     0.5  0.333333
# 24                 Brighton  0.923077  1.000000     0.0  0.307692
#
#     residential  vibrant  eclectic  attraction  restaurant      vibe  \
# 0      0.000000      0.0     0.000   -1.000000   -0.608696  0.000000
# 1      0.000000      0.0     0.000   -1.000000    0.000000  0.000000
# 2      0.000000      0.0     0.000   -0.384615    0.000000  0.000000
# 3      0.000000     -0.5    -0.375    0.000000    0.000000 -0.500000
# 4      0.000000      0.0     0.000   -0.727273   -1.000000  0.000000
# 5      0.000000      0.0     0.000    0.000000    0.000000  0.000000
# 6      0.000000      0.0     0.000    0.000000   -0.555556  0.000000
# 7      0.000000      0.0     0.000    0.000000   -0.187500  0.000000
# 8      0.000000      0.0     0.000    0.000000   -0.130435  0.000000
# 9      0.000000      0.0     0.000    0.000000    0.000000  0.000000
# 10     0.000000      0.0     0.000    0.000000    0.000000  0.000000
# 11     0.000000      0.0     0.000    0.000000    0.000000  0.000000
# 12     0.000000      0.0     0.000    0.000000    0.000000  0.000000
# 13     0.000000      0.0     0.000    0.000000    0.000000  0.000000
# 14     0.000000      0.0     0.000    0.000000    0.000000  0.000000
# 15     0.000000      0.0     0.000    0.000000    0.000000  0.000000
# 16     0.000000      0.0     0.000    0.000000    0.000000  0.000000
# 17     0.000000      0.0     0.000    0.000000    0.000000  0.000000
# 18     0.000000      0.0     0.000    0.000000   -0.222222  0.000000
# 19     0.000000      0.0     0.000    0.000000    0.000000  0.000000
# 20     1.000000      0.0     0.000    0.000000    0.000000  0.000000
# 21     0.615385      0.0     0.000    0.000000   -0.307692 -0.230769
# 22     0.500000      0.0     0.000    0.000000    0.000000  0.000000
# 23     0.000000      0.0     0.000    0.000000    0.000000  0.000000
# 24     0.538462      0.0     0.000    0.000000    0.000000  0.000000
#
#      theater    hip    center       sum  normalized colors
# 0   0.000000  0.000  0.000000 -1.608696   -1.519603    red
# 1  -0.416667  0.000  0.000000 -1.416667   -1.369976    red
# 2   0.000000  0.000 -1.000000 -1.384615   -1.345002    red
# 3   0.000000 -0.375  0.000000 -1.375000   -1.337510    red
# 4   0.000000  0.000  0.000000 -1.363636   -1.328655    red
# 5   0.000000  0.000 -1.000000 -1.000000   -1.045314    red
# 6   0.000000  0.000  0.000000 -0.555556   -0.699008    red
# 7   0.000000  0.000  0.000000 -0.187500   -0.412223    red
# 8   0.000000  0.000  0.000000 -0.130435   -0.367758    red
# 9   0.000000  0.000 -0.277778 -0.055556   -0.309413    red
# 10  0.000000  0.000  0.000000  0.000000   -0.266125    red
# 11  0.000000  0.000  0.000000  0.000000   -0.266125    red
# 12  0.000000  0.000  0.000000  0.000000   -0.266125    red
# 13  0.000000  0.000  0.000000  0.233333   -0.084314    red
# 14  0.000000  0.000  0.000000  0.562500    0.172168  green
# 15  0.000000  0.000  0.000000  0.571429    0.179126  green
# 16  0.000000  0.000  0.000000  1.000000    0.513064  green
# 17  0.000000  0.000  0.000000  1.166667    0.642928  green
# 18  0.000000  0.000  0.000000  1.444444    0.859370  green
# 19  0.000000 -0.300  0.000000  1.700000    1.058496  green
# 20  0.000000  0.000  0.000000  1.800000    1.136415  green
# 21  0.000000  0.000  0.000000  2.076923    1.352190  green
# 22  0.000000  0.000  0.000000  2.125000    1.389651  green
# 23  0.000000  0.000  0.000000  2.166667    1.422117  green
# 24  0.000000  0.000  0.000000  2.769231    1.891628  green

# %%
# plotting the 
plt.figure(figsize=(15,6))

plt.hlines(y=type_vac['neighborhood'], xmin=0, xmax=type_vac['normalized'], color=type_vac['colors'], alpha=0.7, linewidth=5)
plt.title('Which neighborhoods are vibrant and which are quieter?')
plt.xlabel('Normalized difference form the mean');

# %% [markdown]
# #### Description of all neighborhoods based on word clouds from neighborhood descriptions
# * Allston: quiet, safe and close to university with lots of students living in the area
# * Back Bay: historic and charming quarter with beautiful gardens, near Newbury
# * Bay Village: old neighborhood with townhomes and close to Regency and Loews Hotel
# * Beacon Hill: popular Charles Street located in charming and historic quarter in the heart of Boston
# * Brighton: conveniently located with walking distance from many amenities, safe and quiet
# * Charlestown: one of the oldest, most historic and quaint neighborhoods
# * Chinatown: Vibrant neighborhood with major attractions, restaurants and home to Kennedy Greenway
# * Dorchester: Home to a diverse population, residential, safe and quiet area
# * Downtown: Busy neighborhood with many nearby attractions, such as theaters and the TD Garden
# * East Boston: Centrally located at the harbor, originally a shipbuilding district with a diverse population
# * Fenway Park: Close to Harvard Medical School with cobblestone streets and some attractions, such as restaurants and cinemas
# * Hyde Park: Family friendly, quiet and safe, southernmost neighborhood
# * Jamaica Plain: Eclectic, diverse and vibrant neighborhood with a great vibe
# * Leather District: Financial district, center of Boston with everything close by
# * Longwood Medical Area: Residential area
# * Mattapan: Primarily residential area with parks and a beach area; close to Milton
# * Mission Hill: Lots of nearby restaurants, safe and quiet with residential parts
# * North End: historic neighborhood with many cafes and restaurants, family friendly and home to Little Italy
# * Roslindale: Quiet, family-friendly village, hip and diverse neighborhood
# * Roxbury: Peaceful and architecturally interesting area with Fort Hill and Highland Park located there
# * South Boston: Quiet with walking distance from many bars, restaurants and the beach
# * South Boston Waterfront: one of the most popular neighborhoods with barren waterfront, the seaport and many restaurants
# * South End: Conveniently located in the heart of boston, close to Boston Commons and with many restaurants
# * West End: Close to Beacon Hill, centrally located nearby many attractions such as TD Garden
# * West Roxbury: Quiet, uncongested, suburban area

# %% [markdown]
# ##### What if I want to be very central, which neighborhoods should I choose?
#
# A quick google search tells us that the center of Boston has the coordinates 42.361145, -71.057083. In order to understand which neighborhoods are closest located to the center of Boston, I will calculate the difference in latitude and longitude of the neighborhoods to the center.

# %%
listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')

# %%
# create separate dataframe with information of distances from center per neighborhood
BOSTON_LONG = -71.057083
BOSTON_LAT = 42.361145

avg_diff_long = listings.groupby('neighbourhood_cleansed')['longitude'].mean()
avg_diff_lat = listings.groupby('neighbourhood_cleansed')['latitude'].mean()

diff_long_df = pd.DataFrame(avg_diff_long)
diff_lat_df = pd.DataFrame(avg_diff_lat)
diff_long_df['neighborhood'] = diff_long_df.index
diff_lat_df['neighborhood'] = diff_lat_df.index
diff_long_df = diff_long_df.reset_index(drop=True)
diff_lat_df = diff_lat_df.reset_index(drop=True)

diff_pos_df = pd.merge(diff_long_df, diff_lat_df, on='neighborhood', how='outer')
diff_pos_df = diff_pos_df[['neighborhood', 'latitude', 'longitude']]

diff_pos_df = diff_pos_df.append({'neighborhood': 'Center', 'latitude': BOSTON_LAT, 'longitude': BOSTON_LONG}, ignore_index=True)

diff_pos_df
# Out:
#                neighborhood   latitude  longitude
# 0                   Allston  42.354466 -71.130624
# 1                  Back Bay  42.349465 -71.081209
# 2               Bay Village  42.349222 -71.068435
# 3               Beacon Hill  42.359034 -71.067850
# 4                  Brighton  42.347561 -71.150239
# 5               Charlestown  42.379216 -71.066982
# 6                 Chinatown  42.350481 -71.061289
# 7                Dorchester  42.304301 -71.062219
# 8                  Downtown  42.356562 -71.061080
# 9               East Boston  42.374669 -71.030639
# 10                   Fenway  42.345094 -71.095942
# 11                Hyde Park  42.255385 -71.119341
# 12            Jamaica Plain  42.311871 -71.110171
# 13         Leather District  42.351241 -71.058040
# 14    Longwood Medical Area  42.340455 -71.108317
# 15                 Mattapan  42.275926 -71.081309
# 16             Mission Hill  42.331803 -71.103530
# 17                North End  42.365239 -71.054493
# 18               Roslindale  42.284490 -71.131020
# 19                  Roxbury  42.328182 -71.085445
# 20             South Boston  42.334991 -71.047037
# 21  South Boston Waterfront  42.348804 -71.045027
# 22                South End  42.342239 -71.073943
# 23                 West End  42.364140 -71.068259
# 24             West Roxbury  42.282511 -71.156261
# 25                   Center  42.361145 -71.057083

# %%
# creating new dataframe to store color for plot
temp_df = type_vac[['neighborhood','colors']]
temp_pos_df = pd.merge(temp_df, diff_pos_df, on='neighborhood', how='outer')

# adjusting colors for Center neighborhood and for any colors that are not top green and not top red
temp_pos_df.loc[[25], 'colors'] = 'yellow'
temp_pos_df.loc[[6, 7, 8, 9, 10, 11, 12, 13], 'colors'] = 'coral'
temp_pos_df.loc[[14, 15, 16, 17, 18], 'colors'] = 'lightgreen'

temp_pos_df
# Out:
#                neighborhood      colors   latitude  longitude
# 0                 Chinatown         red  42.350481 -71.061289
# 1                  Downtown         red  42.356562 -71.061080
# 2                  West End         red  42.364140 -71.068259
# 3             Jamaica Plain         red  42.311871 -71.110171
# 4              Mission Hill         red  42.331803 -71.103530
# 5          Leather District         red  42.351241 -71.058040
# 6   South Boston Waterfront       coral  42.348804 -71.045027
# 7                 North End       coral  42.365239 -71.054493
# 8                 South End       coral  42.342239 -71.073943
# 9               East Boston       coral  42.374669 -71.030639
# 10                   Fenway       coral  42.345094 -71.095942
# 11                 Back Bay       coral  42.349465 -71.081209
# 12    Longwood Medical Area       coral  42.340455 -71.108317
# 13              Beacon Hill       coral  42.359034 -71.067850
# 14                  Roxbury  lightgreen  42.328182 -71.085445
# 15              Bay Village  lightgreen  42.349222 -71.068435
# 16             South Boston  lightgreen  42.334991 -71.047037
# 17              Charlestown  lightgreen  42.379216 -71.066982
# 18             West Roxbury  lightgreen  42.282511 -71.156261
# 19               Roslindale       green  42.284490 -71.131020
# 20                 Mattapan       green  42.275926 -71.081309
# 21                  Allston       green  42.354466 -71.130624
# 22               Dorchester       green  42.304301 -71.062219
# 23                Hyde Park       green  42.255385 -71.119341
# 24                 Brighton       green  42.347561 -71.150239
# 25                   Center      yellow  42.361145 -71.057083

# %%
# plotting the distance of each neighborhood from the center and coloring dots corresponding
# to neighborhoods based on either being vibrant or quiet
fig, ax = plt.subplots(figsize=(10,10))

def plot_neighbor(x_val, y_val, text, colors, title, marker_size=70):
    '''
    plotting scatterplot showing distance, vibe and average price (if relevant) of neighborhoods
    INPUT:
    OUTPUT:
    '''
    plt.scatter(x_val, y_val, s=marker_size, color=colors)
    plt.xlabel('Longitude difference from Center')
    plt.ylabel('Latitude difference from Center')
    plt.title(title)

    for i, neigh in enumerate(text):
        ax.annotate(neigh, xy=(x_val[i], y_val[i]), xytext=(0, 6), textcoords='offset pixels', ha='center');

title = 'Which neighborhoods are quiet or vibrant and how far from the center are they?'
plot_neighbor(temp_pos_df['longitude'], temp_pos_df['latitude'], temp_pos_df['neighborhood'], temp_pos_df['colors'], title)

# %% [markdown]
# ## How much of the price you're paying goes towards location?

# %%
avg_price = new_price.rename(index=str, columns={'price': 'avg_price', 'listing_id': 'id'})

price_reg = pd.merge(listings, avg_price, on='id', how='outer')

price_reg
# Out:
#             id                            listing_url       scrape_id  \
# 0     12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1      3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2         6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3      1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4      7651065   https://www.airbnb.com/rooms/7651065  20160906204935
# 5     12386020  https://www.airbnb.com/rooms/12386020  20160906204935
# 6      5706985   https://www.airbnb.com/rooms/5706985  20160906204935
# 7      2843445   https://www.airbnb.com/rooms/2843445  20160906204935
# 8       753446    https://www.airbnb.com/rooms/753446  20160906204935
# 9       849408    https://www.airbnb.com/rooms/849408  20160906204935
# 10    12023024  https://www.airbnb.com/rooms/12023024  20160906204935
# 11     1668313   https://www.airbnb.com/rooms/1668313  20160906204935
# 12     2684840   https://www.airbnb.com/rooms/2684840  20160906204935
# 13    13547301  https://www.airbnb.com/rooms/13547301  20160906204935
# 14     5434353   https://www.airbnb.com/rooms/5434353  20160906204935
# 15      225979    https://www.airbnb.com/rooms/225979  20160906204935
# 16     3420384   https://www.airbnb.com/rooms/3420384  20160906204935
# 17    13512930  https://www.airbnb.com/rooms/13512930  20160906204935
# 18     7482195   https://www.airbnb.com/rooms/7482195  20160906204935
# 19     7252607   https://www.airbnb.com/rooms/7252607  20160906204935
# 20     2583074   https://www.airbnb.com/rooms/2583074  20160906204935
# 21    13251243  https://www.airbnb.com/rooms/13251243  20160906204935
# 22      225834    https://www.airbnb.com/rooms/225834  20160906204935
# 23     6400432   https://www.airbnb.com/rooms/6400432  20160906204935
# 24     5498472   https://www.airbnb.com/rooms/5498472  20160906204935
# 25      894539    https://www.airbnb.com/rooms/894539  20160906204935
# 26      879929    https://www.airbnb.com/rooms/879929  20160906204935
# 27     9218312   https://www.airbnb.com/rooms/9218312  20160906204935
# 28      321328    https://www.airbnb.com/rooms/321328  20160906204935
# 29     1810172   https://www.airbnb.com/rooms/1810172  20160906204935
# ...        ...                                    ...             ...
# 3555  13015653  https://www.airbnb.com/rooms/13015653  20160906204935
# 3556  14849141  https://www.airbnb.com/rooms/14849141  20160906204935
# 3557  14604429  https://www.airbnb.com/rooms/14604429  20160906204935
# 3558  14592644  https://www.airbnb.com/rooms/14592644  20160906204935
# 3559  12915510  https://www.airbnb.com/rooms/12915510  20160906204935
# 3560  14887382  https://www.airbnb.com/rooms/14887382  20160906204935
# 3561  14823430  https://www.airbnb.com/rooms/14823430  20160906204935
# 3562  14881840  https://www.airbnb.com/rooms/14881840  20160906204935
# 3563  11452297  https://www.airbnb.com/rooms/11452297  20160906204935
# 3564  14576706  https://www.airbnb.com/rooms/14576706  20160906204935
# 3565  14335003  https://www.airbnb.com/rooms/14335003  20160906204935
# 3566  14871445  https://www.airbnb.com/rooms/14871445  20160906204935
# 3567  14472678  https://www.airbnb.com/rooms/14472678  20160906204935
# 3568  14574800  https://www.airbnb.com/rooms/14574800  20160906204935
# 3569  14426586  https://www.airbnb.com/rooms/14426586  20160906204935
# 3570   3131519   https://www.airbnb.com/rooms/3131519  20160906204935
# 3571  14592547  https://www.airbnb.com/rooms/14592547  20160906204935
# 3572  14744740  https://www.airbnb.com/rooms/14744740  20160906204935
# 3573  14504583  https://www.airbnb.com/rooms/14504583  20160906204935
# 3574  14743129  https://www.airbnb.com/rooms/14743129  20160906204935
# 3575   5280827   https://www.airbnb.com/rooms/5280827  20160906204935
# 3576  14689681  https://www.airbnb.com/rooms/14689681  20160906204935
# 3577  13750763  https://www.airbnb.com/rooms/13750763  20160906204935
# 3578  14536322  https://www.airbnb.com/rooms/14536322  20160906204935
# 3579  14852179  https://www.airbnb.com/rooms/14852179  20160906204935
# 3580   8373729   https://www.airbnb.com/rooms/8373729  20160906204935
# 3581  14844274  https://www.airbnb.com/rooms/14844274  20160906204935
# 3582  14585486  https://www.airbnb.com/rooms/14585486  20160906204935
# 3583  14603878  https://www.airbnb.com/rooms/14603878  20160906204935
# 3584  14504422  https://www.airbnb.com/rooms/14504422  20160906204935
#
#      last_scraped                                               name  \
# 0      2016-09-07                         Sunny Bungalow in the City
# 1      2016-09-07                  Charming room in pet friendly apt
# 2      2016-09-07                   Mexican Folk Art Haven in Boston
# 3      2016-09-07      Spacious Sunny Bedroom Suite in Historic Home
# 4      2016-09-07                                Come Home to Boston
# 5      2016-09-07                     Private Bedroom + Great Coffee
# 6      2016-09-07                New Lrg Studio apt 15 min to Boston
# 7      2016-09-07                 "Tranquility" on "Top of the Hill"
# 8      2016-09-07                 6 miles away from downtown Boston!
# 9      2016-09-07                  Perfect & Practical Boston Rental
# 10     2016-09-07                  Cozy room in a well located house
# 11     2016-09-07                  Room in Rozzie-Twin Bed-Full Bath
# 12     2016-09-07                 Updated, spacious living in Rozzie
# 13     2016-09-07                      2 Bedroom Apartment in Boston
# 14     2016-09-07                            Quiet  Beauty in Boston
# 15     2016-09-07                   Cozy Room & Fresh Roasted Coffee
# 16     2016-09-07                     Convient, Safe and Comfortable
# 17     2016-09-07                Roslindale Beauty next to Arboretum
# 18     2016-09-07                         Private room near bus stop
# 19     2016-09-07                 Private Room near Public Transport
# 20     2016-09-07                     Cozy room in a charming villa.
# 21     2016-09-07                            Arborside Guest Cottage
# 22     2016-09-07                             Skyline View to Boston
# 23     2016-09-07                  Spacious 3 bedroom cape cod style
# 24     2016-09-07                   4BD/3.5BA, Perfect for families!
# 25     2016-09-07                             Private room in house
# 26     2016-09-07                 Surround yourself with custom art!
# 27     2016-09-07                Sunny bedroom with private bathroom
# 28     2016-09-07                Bright Room Near Roslindale Village
# 29     2016-09-07                   Room for 2 in Rozzie - Full Bath
# ...           ...                                                ...
# 3555   2016-09-07               Big Room at Brookline Hill in Boston
# 3556   2016-09-07                             Clean cozy room near T
# 3557   2016-09-07      Bedroom in to Allston/Brookline area for rent
# 3558   2016-09-07  New flat with a terrace in the heart of Cambridge
# 3559   2016-09-07                  It's always more fun on the water
# 3560   2016-09-07               Entire Apt near T/Boston/Harvard/MIT
# 3561   2016-09-07                  Cozy Little Attic Room for Ladies
# 3562   2016-09-07                             Modern hot spot studio
# 3563   2016-09-07                2bed/2bath apt. 3 miles from Boston
# 3564   2016-09-07                               Cozy big room near T
# 3565   2016-09-07               On Charles River near Harvard Square
# 3566   2016-09-07  Private Room with half bathroom inside near Su...
# 3567   2016-09-07                              Cool 5BR in Cambridge
# 3568   2016-09-07                       Clean sunny room near Subway
# 3569   2016-09-07                        Condo for 4 close to Boston
# 3570   2016-09-07                 6# Minutes to Boston-Basic Bedroom
# 3571   2016-09-07       Private Room Boston/Brookline Great location
# 3572   2016-09-07                       NEW - Sunny 5BR in Cambridge
# 3573   2016-09-07                 (J1) Private Room near Harvard/MIT
# 3574   2016-09-07                  Hancock Village rent out one room
# 3575   2016-09-07                                  Private cozy room
# 3576   2016-09-07   Beautiful loft style bedroom with large bathroom
# 3577   2016-09-07        Comfortable Space in the Heart of Brookline
# 3578   2016-09-07                Victorian Garden Level Room - Omega
# 3579   2016-09-07  Spacious Queen Bed Room Close to Boston Univer...
# 3580   2016-09-07                               Big cozy room near T
# 3581   2016-09-07                BU Apartment DexterPark Bright room
# 3582   2016-09-07                           Gorgeous funky apartment
# 3583   2016-09-07              Great Location; Train and Restaurants
# 3584   2016-09-07                 (K1) Private Room near Harvard/MIT
#
#                                                 summary  \
# 0     Cozy, sunny, family home.  Master bedroom high...
# 1     Charming and quiet room in a second floor 1910...
# 2     Come stay with a friendly, middle-aged guy in ...
# 3     Come experience the comforts of home away from...
# 4     My comfy, clean and relaxing home is one block...
# 5     Super comfy bedroom plus your own bathroom in ...
# 6     It's a 5 minute walk to Rosi Square to catch t...
# 7     We can accommodate guests who are gluten-free,...
# 8     Nice and cozy apartment about 6 miles away to ...
# 9     This is a cozy and spacious two bedroom unit w...
# 10    The room is in a single family house located i...
# 11    Quiet second floor bedroom sleeps one in comfo...
# 12    Clean, sunny 2 bedroom in amazing Roslindale V...
# 13    My place is close to Public Transportation. Th...
# 14    Enjoy the full space of our home as you explor...
# 15    Fresh home roasted coffee from around the worl...
# 16    Located along public transportation with plent...
# 17    Clean, sunny 1 bedroom in amazing Roslindale V...
# 18    A handsome colonial house set on a tranquil si...
# 19    A handsome colonial house set on a tranquil si...
# 20    My home is a villa in one of the friendliest, ...
# 21    Lovely sun-filled private guest cottage set on...
# 22    High atop Metropolitan Hill. Expansive view. N...
# 23    Three bedroom in Boston's Roslindale neighborh...
# 24    Our spacious, modern, immaculate town home is ...
# 25                                                  NaN
# 26                                                  NaN
# 27    Located in the Peter's Hill neighborhood, rest...
# 28                                                  NaN
# 29    This second floor bedroom sleeps two in a quee...
# ...                                                 ...
# 3555  The private room is big enough. My place is 5 ...
# 3556  5 min walking to Orange Line subway with 2 sto...
# 3557  My place is close to BU, Brookline (Coolidge C...
# 3558  Located in very center, between Harvard and MI...
# 3559  Our boat is used as a live-aboard and has more...
# 3560  Cozy entire apartment on the ground floor, loc...
# 3561  My place is close to Brookline Village, Coolid...
# 3562  Modern cozy apartment with amazing location ri...
# 3563  Newly renovated apartment available: - Updated...
# 3564  5 min walking to Orange Line subway with 2 sto...
# 3565  My place is a block from the Charles River, a ...
# 3566  My place is good for couples, solo adventurers...
# 3567  3 reasons why you should stay at this Flatbook...
# 3568  5 min walking to Orange Line subway with 2 sto...
# 3569  1 private BR w/ full size bed and bath + a que...
# 3570  Locate at the Green Line subway terminal, walk...
# 3571  My place is close to 4Acoffee, Starbucks, Harr...
# 3572  This sunny Cambridge apartment boasts expansiv...
# 3573  My place is close to My home is a warm and fri...
# 3574  我的房源走路2 minutes有shopping mall,包括CVS,restuarant...
# 3575  Cozy room near T station. 5 min walking to T, ...
# 3576  You'd be living on the top floor of a four sto...
# 3577  Our place is close to Coolidge Corner, Allston...
# 3578  Exquisite garden level (semi basement) room in...
# 3579  - Grocery: A full-size Star market is 2 minute...
# 3580  5 min walking to Orange Line subway with 2 sto...
# 3581  Most popular apartment in BU, best located in ...
# 3582  Funky little apartment close to public transpo...
# 3583  My place is close to Taco Loco Mexican Grill, ...
# 3584  My place is close to My home is a warm and fri...
#
#                                                   space  \
# 0     The house has an open and cozy feel at the sam...
# 1     Small but cozy and quite room with a full size...
# 2     Come stay with a friendly, middle-aged guy in ...
# 3     Most places you find in Boston are small howev...
# 4     Clean, attractive, private room, one block fro...
# 5     Our sunny condo is located on the second and t...
# 6     The whole house was recently redone and it 's ...
# 7     We provide a bedroom and full shared bath.  Ra...
# 8     Nice and cozy apartment about 6 miles away to ...
# 9     Perfect apartment rental for those in town vis...
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14    Large living and dining area. Sprawling space....
# 15    This is a charming, bright, and sunny apartmen...
# 16    Extra large studio with wifi, cable, original ...
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20    The room is cozy and private. The house is les...
# 21    Today the cottage could be called a "tiny hous...
# 22    After a good nights' sleep you will wake each ...
# 23    This Cape Cod style home features two bedrooms...
# 24    Our 2,400+ square foot home is a hidden gem, t...
# 25    Large private room in a large house near the A...
# 26    One big bedroom in a three bedroom Apartment i...
# 27    Large sunny bedroom with double bed, love seat...
# 28    I have an attractive room available in Roslind...
# 29                                                  NaN
# ...                                                 ...
# 3555  Your private room is big enough. And the livin...
# 3556                                                NaN
# 3557                                                NaN
# 3558                                                NaN
# 3559  This 1965 Hatteras 50 foot motor-yacht was ful...
# 3560                                                NaN
# 3561  - *Ladies only!* - The room has 2 mattresses (...
# 3562       Super accessible to every outlet of the city
# 3563  Spacious first floor unit with private porch i...
# 3564                                                NaN
# 3565                                                NaN
# 3566                                                NaN
# 3567  3 reasons why you should stay at this Flatbook...
# 3568                                                NaN
# 3569                                                NaN
# 3570                                                NaN
# 3571  Its a small room but cozy and comfortable. Per...
# 3572  When you walk through the front door of this F...
# 3573  To ensure a smooth check in: 1. You MUST have ...
# 3574                                                NaN
# 3575                                                NaN
# 3576                                                NaN
# 3577  This space consists of 2 Rooms and a private b...
# 3578  Very safe, bustling with shops, restaurants, H...
# 3579                                                NaN
# 3580                                                NaN
# 3581                                Best location in BU
# 3582  Modern and relaxed space with many facilities ...
# 3583                                                NaN
# 3584  To ensure a smooth check in: 1. You MUST have ...
#
#                                             description experiences_offered  \
# 0     Cozy, sunny, family home.  Master bedroom high...                none
# 1     Charming and quiet room in a second floor 1910...                none
# 2     Come stay with a friendly, middle-aged guy in ...                none
# 3     Come experience the comforts of home away from...                none
# 4     My comfy, clean and relaxing home is one block...                none
# 5     Super comfy bedroom plus your own bathroom in ...                none
# 6     It's a 5 minute walk to Rosi Square to catch t...                none
# 7     We can accommodate guests who are gluten-free,...                none
# 8     Nice and cozy apartment about 6 miles away to ...                none
# 9     This is a cozy and spacious two bedroom unit w...                none
# 10    The room is in a single family house located i...                none
# 11    Quiet second floor bedroom sleeps one in comfo...                none
# 12    Clean, sunny 2 bedroom in amazing Roslindale V...                none
# 13    My place is close to Public Transportation. Th...                none
# 14    Enjoy the full space of our home as you explor...                none
# 15    Fresh home roasted coffee from around the worl...                none
# 16    Located along public transportation with plent...                none
# 17    Clean, sunny 1 bedroom in amazing Roslindale V...                none
# 18    A handsome colonial house set on a tranquil si...                none
# 19    A handsome colonial house set on a tranquil si...                none
# 20    My home is a villa in one of the friendliest, ...                none
# 21    Lovely sun-filled private guest cottage set on...                none
# 22    High atop Metropolitan Hill. Expansive view. N...                none
# 23    Three bedroom in Boston's Roslindale neighborh...                none
# 24    Our spacious, modern, immaculate town home is ...                none
# 25    Large private room in a large house near the A...                none
# 26    One big bedroom in a three bedroom Apartment i...                none
# 27    Located in the Peter's Hill neighborhood, rest...                none
# 28    I have an attractive room available in Roslind...                none
# 29    This second floor bedroom sleeps two in a quee...                none
# ...                                                 ...                 ...
# 3555  The private room is big enough. My place is 5 ...                none
# 3556  5 min walking to Orange Line subway with 2 sto...                none
# 3557  My place is close to BU, Brookline (Coolidge C...                none
# 3558  Located in very center, between Harvard and MI...                none
# 3559  Our boat is used as a live-aboard and has more...                none
# 3560  Cozy entire apartment on the ground floor, loc...                none
# 3561  My place is close to Brookline Village, Coolid...                none
# 3562  Modern cozy apartment with amazing location ri...                none
# 3563  Newly renovated apartment available: - Updated...                none
# 3564  5 min walking to Orange Line subway with 2 sto...                none
# 3565  My place is a block from the Charles River, a ...                none
# 3566  My place is good for couples, solo adventurers...                none
# 3567  3 reasons why you should stay at this Flatbook...                none
# 3568  5 min walking to Orange Line subway with 2 sto...                none
# 3569  1 private BR w/ full size bed and bath + a que...                none
# 3570  Locate at the Green Line subway terminal, walk...                none
# 3571  My place is close to 4Acoffee, Starbucks, Harr...                none
# 3572  This sunny Cambridge apartment boasts expansiv...                none
# 3573  My place is close to My home is a warm and fri...                none
# 3574  我的房源走路2 minutes有shopping mall,包括CVS,restuarant...                none
# 3575  Cozy room near T station. 5 min walking to T, ...                none
# 3576  You'd be living on the top floor of a four sto...                none
# 3577  Our place is close to Coolidge Corner, Allston...                none
# 3578  Exquisite garden level (semi basement) room in...                none
# 3579  - Grocery: A full-size Star market is 2 minute...                none
# 3580  5 min walking to Orange Line subway with 2 sto...                none
# 3581  Most popular apartment in BU, best located in ...                none
# 3582  Funky little apartment close to public transpo...                none
# 3583  My place is close to Taco Loco Mexican Grill, ...                none
# 3584  My place is close to My home is a warm and fri...                none
#
#                                   neighborhood_overview  \
# 0     Roslindale is quiet, convenient and friendly. ...
# 1     The room is in Roslindale, a diverse and prima...
# 2     The LOCATION: Roslindale is a safe and diverse...
# 3     Roslindale is a lovely little neighborhood loc...
# 4     I love the proximity to downtown, the neighbor...
# 5     We love our corner of Roslindale! For quiet wa...
# 6     Roslindale is the new hip area of Boston. Clos...
# 7     Our neighborhood is residential with friendly ...
# 8     Roslindale is a primarily residential neighbor...
# 9     This neighborhood truly has it all.  Good, not...
# 10                                                  NaN
# 11    Our neighborhood is quiet and relaxed. There i...
# 12                                                  NaN
# 13                                                  NaN
# 14    Quiet Roslindale, close to the trendy Jamaica ...
# 15    This is a very quiet neighborhood. So quiet yo...
# 16    Village 1 mile with banks, grocery store, spec...
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20    This a nice multicultural, family neighborhood...
# 21    This Boston location is true gem - just a few ...
# 22    This is a very quiet neighborhood. Guests ofte...
# 23                                                  NaN
# 24    Roslindale is a quiet and family friendly, yet...
# 25                                                  NaN
# 26    This is a safe beautiful neighborhood borderin...
# 27    We have lived in Roslindale since 1985 and hav...
# 28    Roslindale is a vibrant area of Boston, with r...
# 29    Our neighborhood is quiet and relaxed. There i...
# ...                                                 ...
# 3555                                                NaN
# 3556                                                NaN
# 3557                                                NaN
# 3558                                                NaN
# 3559  Charlestown Marina is newly renovated and has ...
# 3560                                                NaN
# 3561  - Brookline is the safest and wealthiest town ...
# 3562  Super nice dining options within arms reach le...
# 3563  Located on a quiet tree lined street, just a s...
# 3564                                                NaN
# 3565                                                NaN
# 3566                                                NaN
# 3567  Cambridge has a distinct vibe all its own; bot...
# 3568                                                NaN
# 3569                                                NaN
# 3570                                                NaN
# 3571  We live in one of Boston's favorite neighborho...
# 3572  Cambridge has a distinct vibe all its own; bot...
# 3573                                                NaN
# 3574  走路2 minutes有shopping mall,包括CVS,restuarant,ban...
# 3575                                                NaN
# 3576                                                NaN
# 3577  Brookline is known for being an excellent and ...
# 3578  Safe, in the midst of all Harvard Square actio...
# 3579                                                NaN
# 3580                                                NaN
# 3581                                                NaN
# 3582  Cambridge is a short walk into Boston, and set...
# 3583                                                NaN
# 3584                                                NaN
#
#                                                   notes  \
# 0                                                   NaN
# 1     If you don't have a US cell phone, you can tex...
# 2     I am in a scenic part of Boston with a couple ...
# 3     Please be mindful of the property as it is old...
# 4     I have one roommate who lives on the lower lev...
# 5                                                   NaN
# 6     Information about the house, wifi pasword and ...
# 7     We love having company and meeting people from...
# 8                                                   NaN
# 9     Please note that this is a second floor apartm...
# 10                                                  NaN
# 11    On work days a hot cereal breakfast is entirel...
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15    If you book late on the same day as your arriv...
# 16    Access to large backyard. Enjoy John's origina...
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20             I speak French, Arabic and some Spanish.
# 21    Enclosed bike storage is available. Let us kno...
# 22    If you book late on the same day as your arriv...
# 23                                                  NaN
# 24    Our town home is part of a 4 unit community.  ...
# 25                                                  NaN
# 26                                                  NaN
# 27    Parking available and nearby buses and commute...
# 28    I was once a great traveller, though I seem to...
# 29    On work days a hot cereal breakfast is entirel...
# ...                                                 ...
# 3555                                                NaN
# 3556                                                NaN
# 3557                                                NaN
# 3558                                                NaN
# 3559  Access to the boat will require card key to ge...
# 3560                                                NaN
# 3561  - Because it is an attic room, this room does ...
# 3562                                                NaN
# 3563                                                NaN
# 3564                                                NaN
# 3565                                                NaN
# 3566                                                NaN
# 3567                                                NaN
# 3568                                                NaN
# 3569                                                NaN
# 3570                                                NaN
# 3571                                                NaN
# 3572                                                NaN
# 3573                                                NaN
# 3574                                                NaN
# 3575                                                NaN
# 3576                                                NaN
# 3577    There is no parking available with this rental.
# 3578                                                NaN
# 3579                                                NaN
# 3580                                                NaN
# 3581                                                NaN
# 3582  Depending on when you arrive, I can be here to...
# 3583                                                NaN
# 3584                                                NaN
#
#                                                 transit  \
# 0     The bus stop is 2 blocks away, and frequent. B...
# 1     Plenty of safe street parking. Bus stops a few...
# 2     PUBLIC TRANSPORTATION: From the house, quick p...
# 3     There are buses that stop right in front of th...
# 4     From Logan Airport  and South Station you have...
# 5     To reach downtown Boston via public transporta...
# 6     The commuter rail (Needham Line) is a 5 minute...
# 7     We are a few minutes walk to public bus servic...
# 8                                                   NaN
# 9     Plenty of on street parking with no restrictio...
# 10                                                  NaN
# 11    We are less than a block from city buses, whic...
# 12                                                  NaN
# 13                                                  NaN
# 14    Steps to Commuter Rail. Needham Line. 15 minut...
# 15    Public transportation in Boston is as good as ...
# 16    Airport pick up service for a nominal fee. Bus...
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20    The bus line to Forest Hills station is just u...
# 21    Steps to the bus stops for Forest Hills (Jamai...
# 22    Public transportation in Boston is as good as ...
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26    Easy access to commuter rail, bus and MBTA. I ...
# 27    Five minutes walk from our house, you can catc...
# 28    There is the commuter rail, and a bus to Fores...
# 29    We are less than a block from city buses, whic...
# ...                                                 ...
# 3555  It is close to Bus 60 and Subway Green Line D-...
# 3556                                                NaN
# 3557                                                NaN
# 3558                                                NaN
# 3559  Walking to the city is about a mile or take a ...
# 3560                                                NaN
# 3561  - T (Train) Stations: Green Line D, Brookline ...
# 3562        Super convenient access to train/uber/train
# 3563  Public transportation/Orange Line Subway/Sulli...
# 3564                                                NaN
# 3565                                                NaN
# 3566                                                NaN
# 3567  While Cambridge is great to travel by foot alo...
# 3568                                                NaN
# 3569  Easy walk to T (.4 miles to Sullivan Station- ...
# 3570                                                NaN
# 3571  The apartment is located one block away from t...
# 3572  While Cambridge is great to travel by foot alo...
# 3573                                                NaN
# 3574  走4 minutes 到51的bus station,十几分钟到orange line和gr...
# 3575                                                NaN
# 3576                                                NaN
# 3577  There are 2 green line trains within walking d...
# 3578                Buses, Subway train, city bicycles.
# 3579                                                NaN
# 3580                                                NaN
# 3581  There is green line, BU shuttle in front of th...
# 3582  Public transport is 5 minuts away, but walking...
# 3583                                                NaN
# 3584                                                NaN
#
#                                                  access  \
# 0     You will have access to 2 bedrooms, a living r...
# 1     Apt has one more bedroom (which I use) and lar...
# 2     I am living in the apartment during your stay,...
# 3     The basement has a washer dryer and gym area. ...
# 4     You will have access to the front and side por...
# 5     Guests are welcome to share our living room an...
# 6     I have an electronic keypad so arrival time ca...
# 7     Amenities include an evening snack upon arriva...
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    Guests are welcome to relax in the first floor...
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15    You can feel free to use almost anything here....
# 16                         Private enterance for guest.
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20    Guest has access to everything in the house, K...
# 21    Unload your luggage from the driveway and find...
# 22    You can feel free to use almost anything here....
# 23                                                  NaN
# 24    Guests will have access to bath and bed linens...
# 25                                                  NaN
# 26    Guests have use of bedroom shared bathroom and...
# 27    Private bedroom and luxury bathroom with separ...
# 28    You are free to use the kitchen and cook as yo...
# 29    Guests are welcome to relax in the first floor...
# ...                                                 ...
# 3555                                                NaN
# 3556                                                NaN
# 3557                                                NaN
# 3558                                                NaN
# 3559  The only areas off limits are the engine rooms...
# 3560                                                NaN
# 3561  - You will have access to the room and the bat...
# 3562  Train 24 hour supermarket across the street 8 ...
# 3563  Guests have access to the entire unit: 2 bedro...
# 3564                                                NaN
# 3565                                                NaN
# 3566                                                NaN
# 3567                                                NaN
# 3568                                                NaN
# 3569  Kitchen/ Living Room/ Balcony/ Grill.. As long...
# 3570                                                NaN
# 3571  Guests can use living room, office space(in ca...
# 3572                                                NaN
# 3573                                                NaN
# 3574                                                NaN
# 3575                                                NaN
# 3576                                                NaN
# 3577                                                NaN
# 3578  Access to kitchen, relaxing private side and b...
# 3579                                                NaN
# 3580                                                NaN
# 3581                                                NaN
# 3582  The whole place including social areas is your...
# 3583                                                NaN
# 3584                                                NaN
#
#                                             interaction  \
# 0                                                   NaN
# 1     If I am at home, I am likely working in my hom...
# 2     ABOUT ME: I'm a laid-back, friendly, unmarried...
# 3     We do live in the house therefore might be som...
# 4     I love my city and really enjoy sharing it wit...
# 5     We're busy but always happy to have guests in ...
# 6     I can interact or not- that is up to you. This...
# 7     We will share with you tips about the area - r...
# 8                                                   NaN
# 9     I'm available for questions anytime before or ...
# 10                                                  NaN
# 11    I'm available for guests as work allows. I'm h...
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15    This is a shared living experience. I live and...
# 16    Friendly, experienced, helpful and on site. Ai...
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20    I enjoy the company of others and would be hap...
# 21    You can be completely independent in this trul...
# 22    This is a shared living experience. I live and...
# 23                                                  NaN
# 24    We will not be present during your stay but wi...
# 25                                                  NaN
# 26    I try to leave guests alone unless they need h...
# 27    We are empty nesters who enjoy hosting guests ...
# 28    I like to meet with guests, hear their stories...
# 29    I'm available for guests as work allows. I'm h...
# ...                                                 ...
# 3555  I am available to offer any help during your s...
# 3556                                                NaN
# 3557                                                NaN
# 3558                     Call me if have any questions.
# 3559  Usually I'm available throughout the day, alon...
# 3560                                                NaN
# 3561  - When I am not around, please feel free to te...
# 3562                           Privacy  it's 100% yours
# 3563  Hosts will be available over phone, text and e...
# 3564                                                NaN
# 3565                                                NaN
# 3566                                                NaN
# 3567  Need more towels? A restaurant recommendation?...
# 3568                                                NaN
# 3569                                                NaN
# 3570                                                NaN
# 3571  We're happy to assist with any necessity and h...
# 3572  Need more towels? A restaurant recommendation?...
# 3573                                                NaN
# 3574                                                NaN
# 3575                                                NaN
# 3576                                                NaN
# 3577  We are typically available to offer assistance...
# 3578  Sparingly, as my wife and I are both busy prof...
# 3579                                                NaN
# 3580                                                NaN
# 3581                                                NaN
# 3582                                                NaN
# 3583                                                NaN
# 3584                                                NaN
#
#                                             house_rules  \
# 0     Clean up and treat the home the way you'd like...
# 1     Pet friendly but please confirm with me if the...
# 2     I encourage you to use my kitchen, cooking and...
# 3     - The bathroom and house are shared so please ...
# 4     Please no smoking in the house, porch or on th...
# 5                     No smoking, please, and no drugs.
# 6     Please no shoes in the house so bring slippers...
# 7     House Guidelines for our BnB We are delighted ...
# 8     - Please clean up after yourself when using th...
# 9     NO SMOKING OR PETS ANYWHERE ON THE PROPERTY 1....
# 10                                                  NaN
# 11    My ideal guests would be warm, friendly, and r...
# 12    - One of the bedroom closets is not accessible...
# 13                                                  NaN
# 14                                                  NaN
# 15    Arrival time can be no later than 9:00PM unles...
# 16    Absolutely no smoking in the building, handlin...
# 17    - Please be mindful of the neighbors, quiet ti...
# 18                                                  NaN
# 19    LAUNDRY - Laundry can be done by the visitor b...
# 20    No smoking, No pets.  No shoes in the house. V...
# 21    - No smoking or open flames on the property - ...
# 22    Arrival time can be no later than 10:00PM. No ...
# 23                                                  NaN
# 24    We take great care of our home and expect you ...
# 25                                                  NaN
# 26    Quiet neighborhood, middle apartment of big ho...
# 27    To treat our home with respect.  No smoking in...
# 28    Please no pets or smoking in the house, though...
# 29    My ideal guests would be warm, friendly, and r...
# ...                                                 ...
# 3555                                                NaN
# 3556  1. No damage to the house or furniture 2. No S...
# 3557                                                NaN
# 3558              This is a non smoking apartment. No l
# 3559  Keep in mind your neighbors are very close.  E...
# 3560  1. No damage to the house or furniture 2. No S...
# 3561                         - No shoes on in the house
# 3562                                                NaN
# 3563  - Please be respectful of the household, if yo...
# 3564  1. No damage to the house or furniture 2. No S...
# 3565  - Washer/dryer coinup in apartment basement. -...
# 3566                                                NaN
# 3567  House Rules 1. All bookings made at least a we...
# 3568  1. No damage to the house or furniture 2. No S...
# 3569  Please know this is my 2 bedroom condo that I ...
# 3570                                                NaN
# 3571             Guests cannot wear shoes in the house.
# 3572  House Rules 1. All bookings made at least a we...
# 3573                                                NaN
# 3574                                                NaN
# 3575  1. No damage to the house or furniture 2. No S...
# 3576                                                NaN
# 3577  - Multiple night discounts apply for 3 or more...
# 3578                                                NaN
# 3579                                                NaN
# 3580  1. No damage to the house or furniture 2. No S...
# 3581                                                NaN
# 3582                                                NaN
# 3583                                                NaN
# 3584                                                NaN
#
#                                           thumbnail_url  \
# 0     https://a2.muscache.com/im/pictures/c0842db1-e...
# 1     https://a1.muscache.com/im/pictures/39327812/d...
# 2     https://a2.muscache.com/im/pictures/6ae8335d-9...
# 3     https://a2.muscache.com/im/pictures/39764190-1...
# 4     https://a1.muscache.com/im/pictures/97154760/8...
# 5     https://a2.muscache.com/im/pictures/930c78b2-f...
# 6     https://a1.muscache.com/im/pictures/103587085/...
# 7     https://a2.muscache.com/im/pictures/df3936c4-c...
# 8     https://a2.muscache.com/im/pictures/b4dd9052-4...
# 9     https://a2.muscache.com/im/pictures/35703100/8...
# 10    https://a2.muscache.com/im/pictures/cc305065-5...
# 11    https://a1.muscache.com/im/pictures/23914014/8...
# 12    https://a2.muscache.com/im/pictures/c15817b4-1...
# 13    https://a2.muscache.com/im/pictures/5ea5e31f-8...
# 14    https://a2.muscache.com/im/pictures/75436925/f...
# 15    https://a1.muscache.com/im/pictures/2052589/ec...
# 16    https://a0.muscache.com/im/pictures/43286634/4...
# 17    https://a2.muscache.com/im/pictures/80b80b24-6...
# 18    https://a2.muscache.com/im/pictures/100311920/...
# 19    https://a0.muscache.com/im/pictures/96058694/e...
# 20    https://a2.muscache.com/im/pictures/47544196/8...
# 21    https://a2.muscache.com/im/pictures/b8dd13e9-a...
# 22    https://a1.muscache.com/im/pictures/2050393/27...
# 23    https://a2.muscache.com/im/pictures/80374049/e...
# 24    https://a0.muscache.com/im/pictures/68660949/b...
# 25    https://a1.muscache.com/im/pictures/23866863/a...
# 26    https://a2.muscache.com/im/pictures/12748345/c...
# 27    https://a2.muscache.com/im/pictures/206f6fb6-d...
# 28    https://a2.muscache.com/im/pictures/3465171/8d...
# 29    https://a0.muscache.com/im/pictures/26518085/4...
# ...                                                 ...
# 3555  https://a2.muscache.com/im/pictures/dbd369c3-e...
# 3556  https://a2.muscache.com/im/pictures/baac231f-9...
# 3557  https://a2.muscache.com/im/pictures/9499e5ca-2...
# 3558  https://a2.muscache.com/im/pictures/2c6af5f0-0...
# 3559  https://a2.muscache.com/im/pictures/65292726-7...
# 3560  https://a2.muscache.com/im/pictures/937db7a6-4...
# 3561  https://a2.muscache.com/im/pictures/f0ab2498-6...
# 3562  https://a2.muscache.com/im/pictures/16153445-5...
# 3563  https://a2.muscache.com/im/pictures/5729f228-6...
# 3564  https://a2.muscache.com/im/pictures/9dd09ecf-b...
# 3565  https://a2.muscache.com/im/pictures/ca07c752-2...
# 3566  https://a2.muscache.com/im/pictures/f9f4d0a9-b...
# 3567  https://a2.muscache.com/im/pictures/99640f7b-0...
# 3568  https://a2.muscache.com/im/pictures/f3b166ee-4...
# 3569  https://a2.muscache.com/im/pictures/e962a72d-5...
# 3570  https://a2.muscache.com/im/pictures/40345552/0...
# 3571  https://a2.muscache.com/im/pictures/892007e8-7...
# 3572  https://a2.muscache.com/im/pictures/de97957e-1...
# 3573  https://a2.muscache.com/im/pictures/51cd6cd0-c...
# 3574  https://a2.muscache.com/im/pictures/cc129367-2...
# 3575  https://a2.muscache.com/im/pictures/116bc87c-8...
# 3576  https://a2.muscache.com/im/pictures/725a70f0-a...
# 3577  https://a2.muscache.com/im/pictures/a998d5cd-8...
# 3578  https://a2.muscache.com/im/pictures/11863155-6...
# 3579  https://a2.muscache.com/im/pictures/02834ef2-7...
# 3580  https://a2.muscache.com/im/pictures/809e828a-c...
# 3581  https://a2.muscache.com/im/pictures/e833ccdc-6...
# 3582  https://a2.muscache.com/im/pictures/eb32a608-a...
# 3583  https://a2.muscache.com/im/pictures/4b56e0c4-6...
# 3584  https://a2.muscache.com/im/pictures/f2b43613-6...
#
#                                              medium_url  \
# 0     https://a2.muscache.com/im/pictures/c0842db1-e...
# 1     https://a1.muscache.com/im/pictures/39327812/d...
# 2     https://a2.muscache.com/im/pictures/6ae8335d-9...
# 3     https://a2.muscache.com/im/pictures/39764190-1...
# 4     https://a1.muscache.com/im/pictures/97154760/8...
# 5     https://a2.muscache.com/im/pictures/930c78b2-f...
# 6     https://a1.muscache.com/im/pictures/103587085/...
# 7     https://a2.muscache.com/im/pictures/df3936c4-c...
# 8     https://a2.muscache.com/im/pictures/b4dd9052-4...
# 9     https://a2.muscache.com/im/pictures/35703100/8...
# 10    https://a2.muscache.com/im/pictures/cc305065-5...
# 11    https://a1.muscache.com/im/pictures/23914014/8...
# 12    https://a2.muscache.com/im/pictures/c15817b4-1...
# 13    https://a2.muscache.com/im/pictures/5ea5e31f-8...
# 14    https://a2.muscache.com/im/pictures/75436925/f...
# 15    https://a1.muscache.com/im/pictures/2052589/ec...
# 16    https://a0.muscache.com/im/pictures/43286634/4...
# 17    https://a2.muscache.com/im/pictures/80b80b24-6...
# ...
# 21                      10.0                 10.0                f      NaN
# 22                       9.0                  9.0                f      NaN
# 23                       9.0                 10.0                f      NaN
# 24                      10.0                 10.0                f      NaN
# 25                       9.0                 10.0                f      NaN
# 26                       9.0                  9.0                f      NaN
# 27                      10.0                 10.0                f      NaN
# 28                       9.0                  9.0                f      NaN
# 29                       9.0                 10.0                f      NaN
# ...                      ...                  ...              ...      ...
# 3555                    10.0                  9.0                f      NaN
# 3556                     NaN                  NaN                f      NaN
# 3557                     NaN                  NaN                f      NaN
# 3558                     NaN                  NaN                f      NaN
# 3559                    10.0                 10.0                f      NaN
# 3560                     NaN                  NaN                f      NaN
# 3561                     NaN                  NaN                f      NaN
# 3562                     NaN                  NaN                f      NaN
# 3563                     NaN                  NaN                f      NaN
# 3564                     NaN                  NaN                f      NaN
# 3565                    10.0                 10.0                f      NaN
# 3566                     NaN                  NaN                f      NaN
# 3567                     NaN                  NaN                f      NaN
# 3568                     6.0                  6.0                f      NaN
# 3569                     NaN                  NaN                f      NaN
# 3570                     9.0                  9.0                f      NaN
# 3571                    10.0                 10.0                f      NaN
# 3572                     NaN                  NaN                f      NaN
# 3573                    10.0                 10.0                f      NaN
# 3574                    10.0                  8.0                f      NaN
# 3575                     8.0                  7.0                f      NaN
# 3576                     NaN                  NaN                f      NaN
# 3577                     NaN                  NaN                f      NaN
# 3578                    10.0                 10.0                f      NaN
# 3579                     NaN                  NaN                f      NaN
# 3580                     8.0                  9.0                f      NaN
# 3581                     NaN                  NaN                f      NaN
# 3582                     NaN                  NaN                f      NaN
# 3583                     8.0                  7.0                f      NaN
# 3584                     NaN                  NaN                f      NaN
#
#       jurisdiction_names instant_bookable cancellation_policy  \
# 0                    NaN                f            moderate
# 1                    NaN                t            moderate
# 2                    NaN                f            moderate
# 3                    NaN                f            moderate
# 4                    NaN                f            flexible
# 5                    NaN                f            flexible
# 6                    NaN                f              strict
# 7                    NaN                f            moderate
# 8                    NaN                f            moderate
# 9                    NaN                f              strict
# 10                   NaN                f            flexible
# 11                   NaN                f            flexible
# 12                   NaN                t            flexible
# 13                   NaN                f            moderate
# 14                   NaN                f            moderate
# 15                   NaN                t              strict
# 16                   NaN                f            flexible
# 17                   NaN                t            flexible
# 18                   NaN                f              strict
# 19                   NaN                f              strict
# 20                   NaN                f            flexible
# 21                   NaN                t            moderate
# 22                   NaN                t              strict
# 23                   NaN                f            flexible
# 24                   NaN                f            moderate
# 25                   NaN                f            moderate
# 26                   NaN                f              strict
# 27                   NaN                f            moderate
# 28                   NaN                f            flexible
# 29                   NaN                f            flexible
# ...                  ...              ...                 ...
# 3555                 NaN                f            moderate
# 3556                 NaN                t              strict
# 3557                 NaN                f            flexible
# 3558                 NaN                f              strict
# 3559                 NaN                f            moderate
# 3560                 NaN                f              strict
# 3561                 NaN                f              strict
# 3562                 NaN                f            flexible
# 3563                 NaN                f            moderate
# 3564                 NaN                t              strict
# 3565                 NaN                t            flexible
# 3566                 NaN                f            flexible
# 3567                 NaN                t              strict
# 3568                 NaN                t              strict
# 3569                 NaN                f            flexible
# 3570                 NaN                f              strict
# 3571                 NaN                f            flexible
# 3572                 NaN                t              strict
# 3573                 NaN                t            flexible
# 3574                 NaN                f            moderate
# 3575                 NaN                t              strict
# 3576                 NaN                f            flexible
# 3577                 NaN                f            flexible
# 3578                 NaN                t              strict
# 3579                 NaN                f            flexible
# 3580                 NaN                t              strict
# 3581                 NaN                f              strict
# 3582                 NaN                f            flexible
# 3583                 NaN                f              strict
# 3584                 NaN                t            flexible
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 0                                f                                f
# 1                                f                                f
# 2                                t                                f
# 3                                f                                f
# 4                                f                                f
# 5                                f                                f
# 6                                f                                f
# 7                                t                                t
# 8                                f                                f
# 9                                f                                f
# 10                               f                                f
# 11                               f                                f
# 12                               f                                f
# 13                               f                                f
# 14                               f                                f
# 15                               f                                f
# 16                               f                                f
# 17                               f                                f
# 18                               f                                f
# 19                               f                                f
# 20                               f                                f
# 21                               f                                f
# 22                               f                                f
# 23                               f                                f
# 24                               f                                f
# 25                               f                                f
# 26                               f                                f
# 27                               f                                f
# 28                               f                                f
# 29                               f                                f
# ...                            ...                              ...
# 3555                             f                                f
# 3556                             f                                f
# 3557                             f                                f
# 3558                             f                                f
# 3559                             f                                f
# 3560                             f                                f
# 3561                             f                                f
# 3562                             f                                f
# 3563                             f                                f
# 3564                             f                                f
# 3565                             f                                f
# 3566                             f                                f
# 3567                             f                                f
# 3568                             f                                f
# 3569                             f                                f
# 3570                             f                                f
# 3571                             f                                f
# 3572                             f                                f
# 3573                             f                                f
# 3574                             f                                f
# 3575                             f                                f
# 3576                             f                                f
# 3577                             f                                f
# 3578                             f                                f
# 3579                             f                                f
# 3580                             f                                f
# 3581                             f                                f
# 3582                             f                                f
# 3583                             f                                f
# 3584                             f                                f
#
#       calculated_host_listings_count  reviews_per_month   avg_price
# 0                                  1                NaN         NaN
# 1                                  1               1.30   67.813370
# 2                                  1               0.47   65.000000
# 3                                  1               1.00   75.000000
# 4                                  1               2.25   79.000000
# 5                                  1               1.70   75.000000
# 6                                  3               4.00  111.755814
# 7                                  2               2.38   75.000000
# 8                                  1               5.36   59.363112
# 9                                  2               1.01  252.925234
# 10                                 1               0.36   54.311953
# 11                                 2               0.48   57.000000
# 12                                 2               0.64         NaN
# 13                                 1               4.93  150.000000
# 14                                 1               0.56  145.000000
# 15                                 2               1.16   60.000000
# 16                                 1               1.00  166.418338
# 17                                 2               0.37         NaN
# 18                                 3                NaN   49.000000
# 19                                 3               0.29   49.000000
# 20                                 3               1.24   40.075301
# 21                                 1               5.93  126.449275
# 22                                 2               0.63   70.000000
# 23                                 1               1.58         NaN
# 24                                 1               0.07         NaN
# 25                                 2               1.13   95.000000
# 26                                 1               1.06   90.000000
# 27                                 1               4.02   99.953271
# 28                                 1               0.21  100.000000
# 29                                 2               0.58   67.209677
# ...                              ...                ...         ...
# 3555                               1               4.00   39.000000
# 3556                               8                NaN   70.667590
# 3557                               1                NaN   60.000000
# 3558                               1                NaN  197.408759
# 3559                               1               1.28  285.986301
# 3560                               8                NaN  249.000000
# 3561                               1                NaN   72.515942
# 3562                               1                NaN  179.000000
# 3563                               1                NaN  199.000000
# 3564                               8                NaN   75.000000
# 3565                               1               1.00         NaN
# 3566                               1                NaN   75.120448
# 3567                              58                NaN         NaN
# 3568                               8               1.00   70.655556
# 3569                               1                NaN  200.000000
# 3570                               6               0.29   74.894737
# 3571                               1               2.00         NaN
# 3572                              58                NaN  576.558140
# 3573                               3               2.00   64.547059
# 3574                               2               1.00   68.000000
# 3575                               8               0.33   70.702247
# 3576                               1                NaN  137.945455
# 3577                               1                NaN  122.222222
# 3578                               2               2.00   85.000000
# 3579                               1                NaN   95.739130
# 3580                               8               0.34   70.657303
# 3581                               2                NaN  150.000000
# 3582                               1                NaN  123.275000
# 3583                               1               2.00   59.000000
# 3584                               3                NaN   64.781818
#
# [3585 rows x 96 columns]

# %%
# Drop rows that have the avg_price value missing
price_reg = price_reg.dropna(axis=0, subset=['avg_price'], how='any')

# %%
# average price per neighborhood
neighborhood_price = pd.DataFrame(price_reg.groupby('neighbourhood_cleansed')['avg_price'].mean())

neighborhood_price['neighborhood'] = neighborhood_price.index
neighborhood_price = neighborhood_price.reset_index(drop=True)
neighborhood_price.sort_values('avg_price', inplace=True)

# %%
price_pos_df = pd.merge(temp_pos_df, neighborhood_price, on='neighborhood', how='outer')
price_pos_df.loc[[25], 'avg_price'] = 70

# %%
# plotting the distance of each neighborhood from the center and coloring dots corresponding
# to neighborhoods based on either being vibrant or quiet
# also changing the size of the points based on average price in the neighborhood
fig, ax = plt.subplots(figsize=(10,10))

title = 'Does location and business of neighborhoods play a role for average prices?'
plot_neighbor(price_pos_df['longitude'], price_pos_df['latitude'], price_pos_df['neighborhood'], price_pos_df['colors'], title, marker_size=price_pos_df['avg_price']);

# %%
# adding column with normalized prices
normalization = lambda x: (x - np.mean(neighborhood_price['avg_price']))/np.std(neighborhood_price['avg_price'])
neighborhood_price['normalize'] = neighborhood_price['avg_price'].apply(normalization)
neighborhood_price = neighborhood_price.reset_index(drop=True)
neighborhood_price['colors'] = ['red' if val > 0 else 'green' for val in neighborhood_price['normalize'] ]

# %%
# plotting prices
# similar solution seen on https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python/

fig, ax = plt.subplots(figsize=(15,6))
plt.hlines(y=neighborhood_price['neighborhood'], xmin=0, xmax=neighborhood_price['normalize'], color=neighborhood_price['colors'], alpha=0.7, linewidth=5);

ann_text = neighborhood_price['avg_price']
for norm, neigh, price in zip(neighborhood_price['normalize'], neighborhood_price['neighborhood'], ann_text):
    text = plt.text(norm, neigh, round(price, 2), horizontalalignment='right' if norm < 0 else 'left', verticalalignment='center', fontdict={'color':'darkred' if norm > 0 else 'darkgreen'})

label = ['0', '75', '112', '155', '198', '240', '280', '325']
ax.set_xticklabels(label)
plt.xlabel('Average price per neighborhood')
plt.title('Average prices per neighborhood');

# %%
price_reg.head()
# Out:
#          id                            listing_url       scrape_id  \
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
# 5  12386020  https://www.airbnb.com/rooms/12386020  20160906204935
#
#   last_scraped                                           name  \
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
# 5   2016-09-07                 Private Bedroom + Great Coffee
#
#                                              summary  \
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
# 5  Super comfy bedroom plus your own bathroom in ...
#
#                                                space  \
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
# 5  Our sunny condo is located on the second and t...
#
#                                          description experiences_offered  \
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
# 5  Super comfy bedroom plus your own bathroom in ...                none
#
#                                neighborhood_overview  \
# 1  The room is in Roslindale, a diverse and prima...
# 2  The LOCATION: Roslindale is a safe and diverse...
# 3  Roslindale is a lovely little neighborhood loc...
# 4  I love the proximity to downtown, the neighbor...
# 5  We love our corner of Roslindale! For quiet wa...
#
#                                                notes  \
# 1  If you don't have a US cell phone, you can tex...
# 2  I am in a scenic part of Boston with a couple ...
# 3  Please be mindful of the property as it is old...
# 4  I have one roommate who lives on the lower lev...
# 5                                                NaN
#
#                                              transit  \
# 1  Plenty of safe street parking. Bus stops a few...
# 2  PUBLIC TRANSPORTATION: From the house, quick p...
# 3  There are buses that stop right in front of th...
# 4  From Logan Airport  and South Station you have...
# 5  To reach downtown Boston via public transporta...
#
#                                               access  \
# 1  Apt has one more bedroom (which I use) and lar...
# 2  I am living in the apartment during your stay,...
# 3  The basement has a washer dryer and gym area. ...
# 4  You will have access to the front and side por...
# 5  Guests are welcome to share our living room an...
#
#                                          interaction  \
# 1  If I am at home, I am likely working in my hom...
# 2  ABOUT ME: I'm a laid-back, friendly, unmarried...
# 3  We do live in the house therefore might be som...
# 4  I love my city and really enjoy sharing it wit...
# 5  We're busy but always happy to have guests in ...
#
#                                          house_rules  \
# 1  Pet friendly but please confirm with me if the...
# 2  I encourage you to use my kitchen, cooking and...
# 3  - The bathroom and house are shared so please ...
# 4  Please no smoking in the house, porch or on th...
# 5                  No smoking, please, and no drugs.
#
#                                        thumbnail_url  \
# 1  https://a1.muscache.com/im/pictures/39327812/d...
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...
# 3  https://a2.muscache.com/im/pictures/39764190-1...
# 4  https://a1.muscache.com/im/pictures/97154760/8...
# 5  https://a2.muscache.com/im/pictures/930c78b2-f...
#
#                                           medium_url  \
# 1  https://a1.muscache.com/im/pictures/39327812/d...
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...
# 3  https://a2.muscache.com/im/pictures/39764190-1...
# 4  https://a1.muscache.com/im/pictures/97154760/8...
# 5  https://a2.muscache.com/im/pictures/930c78b2-f...
#
#                                          picture_url  \
# 1  https://a1.muscache.com/im/pictures/39327812/d...
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...
# 3  https://a2.muscache.com/im/pictures/39764190-1...
# 4  https://a1.muscache.com/im/pictures/97154760/8...
# 5  https://a2.muscache.com/im/pictures/930c78b2-f...
#
#                                       xl_picture_url   host_id  \
# 1  https://a1.muscache.com/im/pictures/39327812/d...   2572247
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...     16701
# 3  https://a2.muscache.com/im/pictures/39764190-1...   6031442
# 4  https://a1.muscache.com/im/pictures/97154760/8...  15396970
# 5  https://a2.muscache.com/im/pictures/930c78b2-f...  64200298
#
#                                      host_url host_name  host_since  \
# 1   https://www.airbnb.com/users/show/2572247    Andrea  2012-06-07
# 2     https://www.airbnb.com/users/show/16701      Phil  2009-05-11
# 3   https://www.airbnb.com/users/show/6031442    Meghna  2013-04-21
# 4  https://www.airbnb.com/users/show/15396970     Linda  2014-05-11
# 5  https://www.airbnb.com/users/show/64200298   Deborah  2016-03-23
#
#                           host_location  \
# 1  Boston, Massachusetts, United States
# 2  Boston, Massachusetts, United States
# 3  Boston, Massachusetts, United States
# 4  Boston, Massachusetts, United States
# 5  Boston, Massachusetts, United States
#
#                                           host_about  host_response_time  \
# 1  I live in Boston and I like to travel and have...      within an hour
# 2  I am a middle-aged, single male with a wide ra...  within a few hours
# 3  My husband and I live on the property.  He’s a...  within a few hours
# 4  I work full time for a public school district....      within an hour
# 5                                                NaN  within a few hours
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 1               100%                 100%                 f
# 2               100%                  88%                 t
# 3               100%                  50%                 f
# 4               100%                 100%                 t
# 5               100%                  95%                 t
#
#                                   host_thumbnail_url  \
# 1  https://a2.muscache.com/im/users/2572247/profi...
# 2  https://a2.muscache.com/im/users/16701/profile...
# 3  https://a2.muscache.com/im/pictures/5d430cde-7...
# 4  https://a0.muscache.com/im/users/15396970/prof...
# 5  https://a2.muscache.com/im/pictures/ab20c2a0-8...
#
#                                     host_picture_url host_neighbourhood  \
# 1  https://a2.muscache.com/im/users/2572247/profi...         Roslindale
# 2  https://a2.muscache.com/im/users/16701/profile...         Roslindale
# 3  https://a2.muscache.com/im/pictures/5d430cde-7...                NaN
# 4  https://a0.muscache.com/im/users/15396970/prof...         Roslindale
# 5  https://a2.muscache.com/im/pictures/ab20c2a0-8...         Roslindale
#
#    host_listings_count  host_total_listings_count  \
# 1                    1                          1
# 2                    1                          1
# 3                    1                          1
# 4                    1                          1
# 5                    2                          2
#
#                                   host_verifications host_has_profile_pic  \
# 1  ['email', 'phone', 'facebook', 'linkedin', 'am...                    t
# 2             ['email', 'phone', 'reviews', 'jumio']                    t
# 3                      ['email', 'phone', 'reviews']                    t
# 4               ['email', 'phone', 'reviews', 'kba']                    t
# 5               ['email', 'phone', 'reviews', 'kba']                    t
#
#   host_identity_verified                                             street  \
# 1                      t  Pinehurst Street, Boston, MA 02131, United States
# 2                      t        Ardale St., Boston, MA 02131, United States
# 3                      f                          Boston, MA, United States
# 4                      t    Durnell Avenue, Boston, MA 02131, United States
# 5                      t     Walter Street, Boston, MA 02131, United States
#
#   neighbourhood neighbourhood_cleansed  neighbourhood_group_cleansed    city  \
# 1    Roslindale             Roslindale                           NaN  Boston
# 2    Roslindale             Roslindale                           NaN  Boston
# 3           NaN             Roslindale                           NaN  Boston
# 4    Roslindale             Roslindale                           NaN  Boston
# 5    Roslindale             Roslindale                           NaN  Boston
#
#   state zipcode  market smart_location country_code        country   latitude  \
# 1    MA   02131  Boston     Boston, MA           US  United States  42.286241
# 2    MA   02131  Boston     Boston, MA           US  United States  42.292438
# 3    MA     NaN  Boston     Boston, MA           US  United States  42.281106
# 4    MA   02131  Boston     Boston, MA           US  United States  42.284512
# 5    MA   02131  Boston     Boston, MA           US  United States  42.291690
#
#    longitude is_location_exact property_type     room_type  accommodates  \
# 1 -71.134374                 t     Apartment  Private room             2
# 2 -71.135765                 t     Apartment  Private room             2
# 3 -71.121021                 f         House  Private room             4
# 4 -71.136258                 t         House  Private room             2
# 5 -71.131893                 t   Condominium  Private room             2
#
#    bathrooms  bedrooms  beds  bed_type  \
# 1        1.0       1.0   1.0  Real Bed
# 2        1.0       1.0   1.0  Real Bed
# 3        1.0       1.0   2.0  Real Bed
# 4        1.5       1.0   2.0  Real Bed
# 5        1.0       1.0   1.0  Real Bed
#
#                                            amenities  square_feet   price  \
# 1  {TV,Internet,"Wireless Internet","Air Conditio...          NaN  $65.00
# 2  {TV,"Cable TV","Wireless Internet","Air Condit...          NaN  $65.00
# 3  {TV,Internet,"Wireless Internet","Air Conditio...          NaN  $75.00
# 4  {Internet,"Wireless Internet","Air Conditionin...          NaN  $79.00
# 5  {"Cable TV","Wireless Internet","Air Condition...          NaN  $75.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 1      $400.00           NaN           $95.00       $10.00                0
# 2      $395.00     $1,350.00              NaN          NaN                1
# 3          NaN           NaN          $100.00       $50.00                2
# 4          NaN           NaN              NaN       $15.00                1
# 5          NaN           NaN              NaN       $30.00                1
#
#   extra_people  minimum_nights  maximum_nights calendar_updated  \
# 1        $0.00               2              15       a week ago
# 2       $20.00               3              45       5 days ago
# 3       $25.00               1            1125       a week ago
# 4        $0.00               2              31      2 weeks ago
# 5        $0.00               2            1125      2 weeks ago
#
#    has_availability  availability_30  availability_60  availability_90  \
# 1               NaN               26               54               84
# 2               NaN               19               46               61
# 3               NaN                6               16               26
# 4               NaN               13               34               59
# 5               NaN                5               28               58
#
#    availability_365 calendar_last_scraped  number_of_reviews first_review  \
# 1               359            2016-09-06                 36   2014-06-01
# 2               319            2016-09-06                 41   2009-07-19
# 3                98            2016-09-06                  1   2016-08-28
# 4               334            2016-09-06                 29   2015-08-18
# 5                58            2016-09-06                  8   2016-04-20
#
#   last_review  review_scores_rating  review_scores_accuracy  \
# 1  2016-08-13                  94.0                    10.0
# 2  2016-08-05                  98.0                    10.0
# 3  2016-08-28                 100.0                    10.0
# 4  2016-09-01                  99.0                    10.0
# 5  2016-08-28                 100.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 1                        9.0                   10.0
# 2                        9.0                   10.0
# 3                       10.0                   10.0
# 4                       10.0                   10.0
# 5                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 1                         10.0                     9.0                  9.0
# 2                         10.0                     9.0                 10.0
# 3                         10.0                    10.0                 10.0
# 4                         10.0                     9.0                 10.0
# 5                         10.0                     9.0                 10.0
#
#   requires_license  license  jurisdiction_names instant_bookable  \
# 1                f      NaN                 NaN                t
# 2                f      NaN                 NaN                f
# 3                f      NaN                 NaN                f
# 4                f      NaN                 NaN                f
# 5                f      NaN                 NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 1            moderate                             f
# 2            moderate                             t
# 3            moderate                             f
# 4            flexible                             f
# 5            flexible                             f
#
#   require_guest_phone_verification  calculated_host_listings_count  \
# 1                                f                               1
# 2                                f                               1
# 3                                f                               1
# 4                                f                               1
# 5                                f                               1
#
#    reviews_per_month  avg_price
# 1               1.30   67.81337
# 2               0.47   65.00000
# 3               1.00   75.00000
# 4               2.25   79.00000
# 5               1.70   75.00000

# %% [markdown]
# Looking at the different features I have available, I will drop some of them where I don't think they will be useful

# %%
drop_col = ['listing_url', 'scrape_id', 'last_scraped']
price_reg = price_reg.drop(drop_col, axis=1)

# %%
# check whether experiences_offered has any values aside from 'none'
for row in price_reg['experiences_offered']:
    if row != 'none' and row != np.nan:
        print(row)
        
# remove this column from the dataframe
price_reg = price_reg.drop('experiences_offered', axis=1)

# %%
# remove all columns that have urls
drop_url = ['thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url', 'host_url', 'host_thumbnail_url', 'host_picture_url']
price_reg = price_reg.drop(drop_url, axis=1)

# remove all ids and names which will not generalize well in a ML algorithm
drop_names = ['host_id', 'host_name', 'id']
price_reg = price_reg.drop(drop_names, axis=1)

# %%
print(price_reg['square_feet'].isnull().sum())
price_reg.shape
# Out:
# 2855
# (2906, 82)

# %%
# remove superfluous columns
drop_sup = ['city', 'state', 'neighbourhood', 'neighbourhood_group_cleansed', 'market', 'smart_location', 'country', 'country_code']
price_reg = price_reg.drop(drop_sup, axis=1)

price_reg
# Out:
#                                                    name  \
# 1                     Charming room in pet friendly apt
# 2                      Mexican Folk Art Haven in Boston
# 3         Spacious Sunny Bedroom Suite in Historic Home
# 4                                   Come Home to Boston
# 5                        Private Bedroom + Great Coffee
# 6                   New Lrg Studio apt 15 min to Boston
# 7                    "Tranquility" on "Top of the Hill"
# 8                    6 miles away from downtown Boston!
# 9                     Perfect & Practical Boston Rental
# 10                    Cozy room in a well located house
# 11                    Room in Rozzie-Twin Bed-Full Bath
# 13                        2 Bedroom Apartment in Boston
# 14                              Quiet  Beauty in Boston
# 15                     Cozy Room & Fresh Roasted Coffee
# 16                       Convient, Safe and Comfortable
# 18                           Private room near bus stop
# 19                   Private Room near Public Transport
# 20                       Cozy room in a charming villa.
# 21                              Arborside Guest Cottage
# 22                               Skyline View to Boston
# 25                               Private room in house
# 26                   Surround yourself with custom art!
# 27                  Sunny bedroom with private bathroom
# 28                  Bright Room Near Roslindale Village
# 29                     Room for 2 in Rozzie - Full Bath
# 30                      Private room in spacious condo!
# 31                  Adorable  Apt. 20 min from Downtown
# 32                            1 Bedroom Home Suite Home
# 33                   Private Room near public transport
# 34                   Charming Gambrel on a sweet street
# ...                                                 ...
# 3552                 (N) Shared room near Harvard & MIT
# 3553                             Big simple room near T
# 3554                 2 bedrooms available in 4 bed unit
# 3555               Big Room at Brookline Hill in Boston
# 3556                             Clean cozy room near T
# 3557      Bedroom in to Allston/Brookline area for rent
# 3558  New flat with a terrace in the heart of Cambridge
# 3559                  It's always more fun on the water
# 3560               Entire Apt near T/Boston/Harvard/MIT
# 3561                  Cozy Little Attic Room for Ladies
# 3562                             Modern hot spot studio
# 3563                2bed/2bath apt. 3 miles from Boston
# 3564                               Cozy big room near T
# 3566  Private Room with half bathroom inside near Su...
# 3568                       Clean sunny room near Subway
# 3569                        Condo for 4 close to Boston
# 3570                 6# Minutes to Boston-Basic Bedroom
# 3572                       NEW - Sunny 5BR in Cambridge
# 3573                 (J1) Private Room near Harvard/MIT
# 3574                  Hancock Village rent out one room
# 3575                                  Private cozy room
# 3576   Beautiful loft style bedroom with large bathroom
# 3577        Comfortable Space in the Heart of Brookline
# 3578                Victorian Garden Level Room - Omega
# 3579  Spacious Queen Bed Room Close to Boston Univer...
# 3580                               Big cozy room near T
# 3581                BU Apartment DexterPark Bright room
# 3582                           Gorgeous funky apartment
# 3583              Great Location; Train and Restaurants
# 3584                 (K1) Private Room near Harvard/MIT
#
#                                                 summary  \
# 1     Charming and quiet room in a second floor 1910...
# 2     Come stay with a friendly, middle-aged guy in ...
# 3     Come experience the comforts of home away from...
# 4     My comfy, clean and relaxing home is one block...
# 5     Super comfy bedroom plus your own bathroom in ...
# 6     It's a 5 minute walk to Rosi Square to catch t...
# 7     We can accommodate guests who are gluten-free,...
# 8     Nice and cozy apartment about 6 miles away to ...
# 9     This is a cozy and spacious two bedroom unit w...
# 10    The room is in a single family house located i...
# 11    Quiet second floor bedroom sleeps one in comfo...
# 13    My place is close to Public Transportation. Th...
# 14    Enjoy the full space of our home as you explor...
# 15    Fresh home roasted coffee from around the worl...
# 16    Located along public transportation with plent...
# 18    A handsome colonial house set on a tranquil si...
# 19    A handsome colonial house set on a tranquil si...
# 20    My home is a villa in one of the friendliest, ...
# 21    Lovely sun-filled private guest cottage set on...
# 22    High atop Metropolitan Hill. Expansive view. N...
# 25                                                  NaN
# 26                                                  NaN
# 27    Located in the Peter's Hill neighborhood, rest...
# 28                                                  NaN
# 29    This second floor bedroom sleeps two in a quee...
# 30    Nice unit located within walking distance of c...
# 31    New totally renovated 2 bedroom apt located 30...
# 32    My place is good for couples, solo adventurers...
# 33    A handsome colonial house set on a tranquil si...
# 34    This home has been featured in several magazin...
# ...                                                 ...
# 3552  This bed accommodates 2 and is a shared room w...
# 3553  A spacious bedroom with a folding screen for p...
# 3554  2 bedrooms, 1 with King bed and other with 2 s...
# 3555  The private room is big enough. My place is 5 ...
# 3556  5 min walking to Orange Line subway with 2 sto...
# 3557  My place is close to BU, Brookline (Coolidge C...
# 3558  Located in very center, between Harvard and MI...
# 3559  Our boat is used as a live-aboard and has more...
# 3560  Cozy entire apartment on the ground floor, loc...
# 3561  My place is close to Brookline Village, Coolid...
# 3562  Modern cozy apartment with amazing location ri...
# 3563  Newly renovated apartment available: - Updated...
# 3564  5 min walking to Orange Line subway with 2 sto...
# 3566  My place is good for couples, solo adventurers...
# 3568  5 min walking to Orange Line subway with 2 sto...
# 3569  1 private BR w/ full size bed and bath + a que...
# 3570  Locate at the Green Line subway terminal, walk...
# 3572  This sunny Cambridge apartment boasts expansiv...
# 3573  My place is close to My home is a warm and fri...
# 3574  我的房源走路2 minutes有shopping mall,包括CVS,restuarant...
# 3575  Cozy room near T station. 5 min walking to T, ...
# 3576  You'd be living on the top floor of a four sto...
# 3577  Our place is close to Coolidge Corner, Allston...
# 3578  Exquisite garden level (semi basement) room in...
# 3579  - Grocery: A full-size Star market is 2 minute...
# 3580  5 min walking to Orange Line subway with 2 sto...
# 3581  Most popular apartment in BU, best located in ...
# 3582  Funky little apartment close to public transpo...
# 3583  My place is close to Taco Loco Mexican Grill, ...
# 3584  My place is close to My home is a warm and fri...
#
#                                                   space  \
# 1     Small but cozy and quite room with a full size...
# 2     Come stay with a friendly, middle-aged guy in ...
# 3     Most places you find in Boston are small howev...
# 4     Clean, attractive, private room, one block fro...
# 5     Our sunny condo is located on the second and t...
# 6     The whole house was recently redone and it 's ...
# 7     We provide a bedroom and full shared bath.  Ra...
# 8     Nice and cozy apartment about 6 miles away to ...
# 9     Perfect apartment rental for those in town vis...
# 10                                                  NaN
# 11                                                  NaN
# 13                                                  NaN
# 14    Large living and dining area. Sprawling space....
# 15    This is a charming, bright, and sunny apartmen...
# 16    Extra large studio with wifi, cable, original ...
# 18                                                  NaN
# 19                                                  NaN
# 20    The room is cozy and private. The house is les...
# 21    Today the cottage could be called a "tiny hous...
# 22    After a good nights' sleep you will wake each ...
# 25    Large private room in a large house near the A...
# 26    One big bedroom in a three bedroom Apartment i...
# 27    Large sunny bedroom with double bed, love seat...
# 28    I have an attractive room available in Roslind...
# 29                                                  NaN
# 30    Spacious, modern construction condo with plent...
# 31    New Totally renovated 2 bedroom apartment loca...
# 32                                                  NaN
# 33                                                  NaN
# 34    This beautiful house, filled with a lifetime o...
# ...                                                 ...
# 3552  To ensure a smooth check in: 1. You MUST have ...
# 3553                                                NaN
# 3554                                                NaN
# 3555  Your private room is big enough. And the livin...
# 3556                                                NaN
# 3557                                                NaN
# 3558                                                NaN
# 3559  This 1965 Hatteras 50 foot motor-yacht was ful...
# 3560                                                NaN
# 3561  - *Ladies only!* - The room has 2 mattresses (...
# 3562       Super accessible to every outlet of the city
# 3563  Spacious first floor unit with private porch i...
# 3564                                                NaN
# 3566                                                NaN
# 3568                                                NaN
# 3569                                                NaN
# 3570                                                NaN
# 3572  When you walk through the front door of this F...
# 3573  To ensure a smooth check in: 1. You MUST have ...
# 3574                                                NaN
# 3575                                                NaN
# 3576                                                NaN
# 3577  This space consists of 2 Rooms and a private b...
# 3578  Very safe, bustling with shops, restaurants, H...
# 3579                                                NaN
# 3580                                                NaN
# 3581                                Best location in BU
# 3582  Modern and relaxed space with many facilities ...
# 3583                                                NaN
# 3584  To ensure a smooth check in: 1. You MUST have ...
#
#                                             description  \
# 1     Charming and quiet room in a second floor 1910...
# 2     Come stay with a friendly, middle-aged guy in ...
# 3     Come experience the comforts of home away from...
# 4     My comfy, clean and relaxing home is one block...
# 5     Super comfy bedroom plus your own bathroom in ...
# 6     It's a 5 minute walk to Rosi Square to catch t...
# 7     We can accommodate guests who are gluten-free,...
# 8     Nice and cozy apartment about 6 miles away to ...
# 9     This is a cozy and spacious two bedroom unit w...
# 10    The room is in a single family house located i...
# 11    Quiet second floor bedroom sleeps one in comfo...
# 13    My place is close to Public Transportation. Th...
# 14    Enjoy the full space of our home as you explor...
# 15    Fresh home roasted coffee from around the worl...
# 16    Located along public transportation with plent...
# 18    A handsome colonial house set on a tranquil si...
# 19    A handsome colonial house set on a tranquil si...
# 20    My home is a villa in one of the friendliest, ...
# 21    Lovely sun-filled private guest cottage set on...
# 22    High atop Metropolitan Hill. Expansive view. N...
# 25    Large private room in a large house near the A...
# 26    One big bedroom in a three bedroom Apartment i...
# 27    Located in the Peter's Hill neighborhood, rest...
# 28    I have an attractive room available in Roslind...
# 29    This second floor bedroom sleeps two in a quee...
# 30    Nice unit located within walking distance of c...
# 31    New totally renovated 2 bedroom apt located 30...
# 32    My place is good for couples, solo adventurers...
# 33    A handsome colonial house set on a tranquil si...
# 34    This home has been featured in several magazin...
# ...                                                 ...
# 3552  This bed accommodates 2 and is a shared room w...
# 3553  A spacious bedroom with a folding screen for p...
# 3554  2 bedrooms, 1 with King bed and other with 2 s...
# 3555  The private room is big enough. My place is 5 ...
# 3556  5 min walking to Orange Line subway with 2 sto...
# 3557  My place is close to BU, Brookline (Coolidge C...
# 3558  Located in very center, between Harvard and MI...
# 3559  Our boat is used as a live-aboard and has more...
# 3560  Cozy entire apartment on the ground floor, loc...
# 3561  My place is close to Brookline Village, Coolid...
# 3562  Modern cozy apartment with amazing location ri...
# 3563  Newly renovated apartment available: - Updated...
# 3564  5 min walking to Orange Line subway with 2 sto...
# 3566  My place is good for couples, solo adventurers...
# 3568  5 min walking to Orange Line subway with 2 sto...
# 3569  1 private BR w/ full size bed and bath + a que...
# 3570  Locate at the Green Line subway terminal, walk...
# 3572  This sunny Cambridge apartment boasts expansiv...
# 3573  My place is close to My home is a warm and fri...
# 3574  我的房源走路2 minutes有shopping mall,包括CVS,restuarant...
# 3575  Cozy room near T station. 5 min walking to T, ...
# 3576  You'd be living on the top floor of a four sto...
# 3577  Our place is close to Coolidge Corner, Allston...
# 3578  Exquisite garden level (semi basement) room in...
# 3579  - Grocery: A full-size Star market is 2 minute...
# 3580  5 min walking to Orange Line subway with 2 sto...
# 3581  Most popular apartment in BU, best located in ...
# 3582  Funky little apartment close to public transpo...
# 3583  My place is close to Taco Loco Mexican Grill, ...
# 3584  My place is close to My home is a warm and fri...
#
#                                   neighborhood_overview  \
# 1     The room is in Roslindale, a diverse and prima...
# 2     The LOCATION: Roslindale is a safe and diverse...
# 3     Roslindale is a lovely little neighborhood loc...
# 4     I love the proximity to downtown, the neighbor...
# 5     We love our corner of Roslindale! For quiet wa...
# 6     Roslindale is the new hip area of Boston. Clos...
# 7     Our neighborhood is residential with friendly ...
# 8     Roslindale is a primarily residential neighbor...
# 9     This neighborhood truly has it all.  Good, not...
# 10                                                  NaN
# 11    Our neighborhood is quiet and relaxed. There i...
# 13                                                  NaN
# 14    Quiet Roslindale, close to the trendy Jamaica ...
# 15    This is a very quiet neighborhood. So quiet yo...
# 16    Village 1 mile with banks, grocery store, spec...
# 18                                                  NaN
# 19                                                  NaN
# 20    This a nice multicultural, family neighborhood...
# 21    This Boston location is true gem - just a few ...
# 22    This is a very quiet neighborhood. Guests ofte...
# 25                                                  NaN
# 26    This is a safe beautiful neighborhood borderin...
# 27    We have lived in Roslindale since 1985 and hav...
# 28    Roslindale is a vibrant area of Boston, with r...
# 29    Our neighborhood is quiet and relaxed. There i...
# 30    Today's Roslindale is not the "Rozzie" of my y...
# 31    Access to public transportation it is only two...
# 32                                                  NaN
# 33                                                  NaN
# 34    Our home is located on the top of one of the t...
# ...                                                 ...
# 3552                                                NaN
# 3553                                                NaN
# 3554                                                NaN
# 3555                                                NaN
# 3556                                                NaN
# 3557                                                NaN
# 3558                                                NaN
# 3559  Charlestown Marina is newly renovated and has ...
# 3560                                                NaN
# 3561  - Brookline is the safest and wealthiest town ...
# 3562  Super nice dining options within arms reach le...
# 3563  Located on a quiet tree lined street, just a s...
# 3564                                                NaN
# 3566                                                NaN
# 3568                                                NaN
# 3569                                                NaN
# 3570                                                NaN
# 3572  Cambridge has a distinct vibe all its own; bot...
# 3573                                                NaN
# 3574  走路2 minutes有shopping mall,包括CVS,restuarant,ban...
# 3575                                                NaN
# 3576                                                NaN
# 3577  Brookline is known for being an excellent and ...
# 3578  Safe, in the midst of all Harvard Square actio...
# 3579                                                NaN
# 3580                                                NaN
# 3581                                                NaN
# 3582  Cambridge is a short walk into Boston, and set...
# 3583                                                NaN
# 3584                                                NaN
#
#                                                   notes  \
# 1     If you don't have a US cell phone, you can tex...
# 2     I am in a scenic part of Boston with a couple ...
# 3     Please be mindful of the property as it is old...
# 4     I have one roommate who lives on the lower lev...
# 5                                                   NaN
# 6     Information about the house, wifi pasword and ...
# 7     We love having company and meeting people from...
# 8                                                   NaN
# 9     Please note that this is a second floor apartm...
# 10                                                  NaN
# 11    On work days a hot cereal breakfast is entirel...
# 13                                                  NaN
# 14                                                  NaN
# 15    If you book late on the same day as your arriv...
# 16    Access to large backyard. Enjoy John's origina...
# 18                                                  NaN
# 19                                                  NaN
# 20             I speak French, Arabic and some Spanish.
# 21    Enclosed bike storage is available. Let us kno...
# 22    If you book late on the same day as your arriv...
# 25                                                  NaN
# 26                                                  NaN
# 27    Parking available and nearby buses and commute...
# 28    I was once a great traveller, though I seem to...
# 29    On work days a hot cereal breakfast is entirel...
# 30               There's a laundromat within one block.
# 31                                                  NaN
# 32                                                  NaN
# 33                                                  NaN
# 34    Rita Rose is my constant houseguest and is a s...
# ...                                                 ...
# 3552                                                NaN
# 3553                                                NaN
# 3554                                                NaN
# 3555                                                NaN
# 3556                                                NaN
# 3557                                                NaN
# 3558                                                NaN
# 3559  Access to the boat will require card key to ge...
# 3560                                                NaN
# 3561  - Because it is an attic room, this room does ...
# 3562                                                NaN
# 3563                                                NaN
# 3564                                                NaN
# 3566                                                NaN
# 3568                                                NaN
# 3569                                                NaN
# 3570                                                NaN
# 3572                                                NaN
# 3573                                                NaN
# 3574                                                NaN
# 3575                                                NaN
# 3576                                                NaN
# 3577    There is no parking available with this rental.
# 3578                                                NaN
# 3579                                                NaN
# 3580                                                NaN
# 3581                                                NaN
# 3582  Depending on when you arrive, I can be here to...
# 3583                                                NaN
# 3584                                                NaN
#
#                                                 transit  \
# 1     Plenty of safe street parking. Bus stops a few...
# 2     PUBLIC TRANSPORTATION: From the house, quick p...
# 3     There are buses that stop right in front of th...
# 4     From Logan Airport  and South Station you have...
# 5     To reach downtown Boston via public transporta...
# 6     The commuter rail (Needham Line) is a 5 minute...
# 7     We are a few minutes walk to public bus servic...
# 8                                                   NaN
# 9     Plenty of on street parking with no restrictio...
# 10                                                  NaN
# 11    We are less than a block from city buses, whic...
# 13                                                  NaN
# 14    Steps to Commuter Rail. Needham Line. 15 minut...
# 15    Public transportation in Boston is as good as ...
# 16    Airport pick up service for a nominal fee. Bus...
# 18                                                  NaN
# 19                                                  NaN
# 20    The bus line to Forest Hills station is just u...
# 21    Steps to the bus stops for Forest Hills (Jamai...
# 22    Public transportation in Boston is as good as ...
# 25                                                  NaN
# 26    Easy access to commuter rail, bus and MBTA. I ...
# 27    Five minutes walk from our house, you can catc...
# 28    There is the commuter rail, and a bus to Fores...
# 29    We are less than a block from city buses, whic...
# 30    Located right on the #32 bus route which shoot...
# 31                                                  NaN
# 32                                                  NaN
# 33                                                  NaN
# 34    How easy is this!  At the end of my one block ...
# ...                                                 ...
# 3552                                                NaN
# 3553                                                NaN
# 3554                                                NaN
# 3555  It is close to Bus 60 and Subway Green Line D-...
# 3556                                                NaN
# 3557                                                NaN
# 3558                                                NaN
# 3559  Walking to the city is about a mile or take a ...
# 3560                                                NaN
# 3561  - T (Train) Stations: Green Line D, Brookline ...
# 3562        Super convenient access to train/uber/train
# 3563  Public transportation/Orange Line Subway/Sulli...
# 3564                                                NaN
# 3566                                                NaN
# 3568                                                NaN
# 3569  Easy walk to T (.4 miles to Sullivan Station- ...
# 3570                                                NaN
# 3572  While Cambridge is great to travel by foot alo...
# 3573                                                NaN
# 3574  走4 minutes 到51的bus station,十几分钟到orange line和gr...
# 3575                                                NaN
# 3576                                                NaN
# 3577  There are 2 green line trains within walking d...
# 3578                Buses, Subway train, city bicycles.
# 3579                                                NaN
# 3580                                                NaN
# 3581  There is green line, BU shuttle in front of th...
# 3582  Public transport is 5 minuts away, but walking...
# 3583                                                NaN
# 3584                                                NaN
#
#                                                  access  \
# 1     Apt has one more bedroom (which I use) and lar...
# 2     I am living in the apartment during your stay,...
# 3     The basement has a washer dryer and gym area. ...
# 4     You will have access to the front and side por...
# 5     Guests are welcome to share our living room an...
# 6     I have an electronic keypad so arrival time ca...
# 7     Amenities include an evening snack upon arriva...
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    Guests are welcome to relax in the first floor...
# 13                                                  NaN
# 14                                                  NaN
# 15    You can feel free to use almost anything here....
# 16                         Private enterance for guest.
# 18                                                  NaN
# 19                                                  NaN
# 20    Guest has access to everything in the house, K...
# 21    Unload your luggage from the driveway and find...
# 22    You can feel free to use almost anything here....
# 25                                                  NaN
# 26    Guests have use of bedroom shared bathroom and...
# 27    Private bedroom and luxury bathroom with separ...
# 28    You are free to use the kitchen and cook as yo...
# 29    Guests are welcome to relax in the first floor...
# 30    Access to bedroom, main dining room, TV area, ...
# 31                                                  NaN
# 32                                                  NaN
# 33                                                  NaN
# 34    Your sweet little room is all yours but feel f...
# ...                                                 ...
# 3552                                                NaN
# 3553                                                NaN
# 3554                                                NaN
# 3555                                                NaN
# 3556                                                NaN
# 3557                                                NaN
# 3558                                                NaN
# 3559  The only areas off limits are the engine rooms...
# 3560                                                NaN
# 3561  - You will have access to the room and the bat...
# 3562  Train 24 hour supermarket across the street 8 ...
# 3563  Guests have access to the entire unit: 2 bedro...
# 3564                                                NaN
# 3566                                                NaN
# 3568                                                NaN
# 3569  Kitchen/ Living Room/ Balcony/ Grill.. As long...
# 3570                                                NaN
# 3572                                                NaN
# 3573                                                NaN
# 3574                                                NaN
# 3575                                                NaN
# 3576                                                NaN
# 3577                                                NaN
# 3578  Access to kitchen, relaxing private side and b...
# 3579                                                NaN
# 3580                                                NaN
# 3581                                                NaN
# 3582  The whole place including social areas is your...
# 3583                                                NaN
# 3584                                                NaN
#
#                                             interaction  \
# 1     If I am at home, I am likely working in my hom...
# 2     ABOUT ME: I'm a laid-back, friendly, unmarried...
# 3     We do live in the house therefore might be som...
# 4     I love my city and really enjoy sharing it wit...
# 5     We're busy but always happy to have guests in ...
# 6     I can interact or not- that is up to you. This...
# 7     We will share with you tips about the area - r...
# 8                                                   NaN
# 9     I'm available for questions anytime before or ...
# 10                                                  NaN
# 11    I'm available for guests as work allows. I'm h...
# 13                                                  NaN
# 14                                                  NaN
# 15    This is a shared living experience. I live and...
# 16    Friendly, experienced, helpful and on site. Ai...
# 18                                                  NaN
# 19                                                  NaN
# 20    I enjoy the company of others and would be hap...
# 21    You can be completely independent in this trul...
# 22    This is a shared living experience. I live and...
# 25                                                  NaN
# 26    I try to leave guests alone unless they need h...
# 27    We are empty nesters who enjoy hosting guests ...
# 28    I like to meet with guests, hear their stories...
# 29    I'm available for guests as work allows. I'm h...
# 30    As a native Bostonian I know the area very wel...
# 31    We don't live at this location, but my mother ...
# 32                                                  NaN
# 33                                                  NaN
# 34    We are so happy you will be our guest and once...
# ...                                                 ...
# 3552                                                NaN
# 3553                                                NaN
# 3554                                                NaN
# 3555  I am available to offer any help during your s...
# 3556                                                NaN
# 3557                                                NaN
# 3558                     Call me if have any questions.
# 3559  Usually I'm available throughout the day, alon...
# 3560                                                NaN
# 3561  - When I am not around, please feel free to te...
# 3562                           Privacy  it's 100% yours
# 3563  Hosts will be available over phone, text and e...
# 3564                                                NaN
# 3566                                                NaN
# 3568                                                NaN
# 3569                                                NaN
# 3570                                                NaN
# 3572  Need more towels? A restaurant recommendation?...
# 3573                                                NaN
# 3574                                                NaN
# 3575                                                NaN
# 3576                                                NaN
# 3577  We are typically available to offer assistance...
# 3578  Sparingly, as my wife and I are both busy prof...
# 3579                                                NaN
# 3580                                                NaN
# 3581                                                NaN
# 3582                                                NaN
# 3583                                                NaN
# 3584                                                NaN
#
#                                             house_rules  host_since  \
# 1     Pet friendly but please confirm with me if the...  2012-06-07
# 2     I encourage you to use my kitchen, cooking and...  2009-05-11
# 3     - The bathroom and house are shared so please ...  2013-04-21
# 4     Please no smoking in the house, porch or on th...  2014-05-11
# 5                     No smoking, please, and no drugs.  2016-03-23
# 6     Please no shoes in the house so bring slippers...  2013-05-25
# 7     House Guidelines for our BnB We are delighted ...  2012-08-05
# 8     - Please clean up after yourself when using th...  2012-10-24
# 9     NO SMOKING OR PETS ANYWHERE ON THE PROPERTY 1....  2012-12-18
# 10                                                  NaN  2016-03-24
# 11    My ideal guests would be warm, friendly, and r...  2013-09-14
# 13                                                  NaN  2016-02-04
# 14                                                  NaN  2013-10-27
# 15    Arrival time can be no later than 9:00PM unles...  2011-09-18
# 16    Absolutely no smoking in the building, handlin...  2011-03-09
# 18                                                  NaN  2015-05-30
# 19    LAUNDRY - Laundry can be done by the visitor b...  2015-05-30
# 20    No smoking, No pets.  No shoes in the house. V...  2014-03-17
# 21    - No smoking or open flames on the property - ...  2016-05-28
# 22    Arrival time can be no later than 10:00PM. No ...  2011-09-18
# 25                                                  NaN  2013-01-19
# 26    Quiet neighborhood, middle apartment of big ho...  2013-01-10
# 27    To treat our home with respect.  No smoking in...  2015-11-01
# 28    Please no pets or smoking in the house, though...  2013-08-21
# 29    My ideal guests would be warm, friendly, and r...  2013-09-14
# 30    Just be respectful, clean, and quiet after 10:...  2014-06-04
# 31    No loud noises or loud music. Please help us s...  2015-06-30
# 32                                                  NaN  2015-02-27
# 33    LAUNDRY - Laundry can be done by the visitor b...  2015-05-30
# 34                    Please no smoking on the property  2013-09-16
# ...                                                 ...         ...
# 3552                                                NaN  2015-08-20
# 3553  1. No damage to the house or furniture 2. No S...  2014-07-31
# 3554                                                NaN  2016-08-14
# 3555                                                NaN  2015-10-06
# 3556  1. No damage to the house or furniture 2. No S...  2014-07-31
# 3557                                                NaN  2016-08-18
# 3558              This is a non smoking apartment. No l  2014-04-07
# 3559  Keep in mind your neighbors are very close.  E...  2015-02-25
# 3560  1. No damage to the house or furniture 2. No S...  2014-07-31
# 3561                         - No shoes on in the house  2016-08-30
# 3562                                                NaN  2015-06-28
# 3563  - Please be respectful of the household, if yo...  2016-02-24
# 3564  1. No damage to the house or furniture 2. No S...  2014-07-31
# 3566                                                NaN  2015-05-21
# 3568  1. No damage to the house or furniture 2. No S...  2014-07-31
# 3569  Please know this is my 2 bedroom condo that I ...  2014-09-09
# 3570                                                NaN  2013-05-11
# 3572  House Rules 1. All bookings made at least a we...  2014-02-14
# 3573                                                NaN  2015-08-20
# 3574                                                NaN  2016-08-25
# 3575  1. No damage to the house or furniture 2. No S...  2014-07-31
# 3576                                                NaN  2015-12-04
# 3577  - Multiple night discounts apply for 3 or more...  2015-05-21
# 3578                                                NaN  2016-06-18
# 3579                                                NaN  2016-04-19
# 3580  1. No damage to the house or furniture 2. No S...  2014-07-31
# 3581                                                NaN  2015-07-02
# 3582                                                NaN  2014-01-14
# 3583                                                NaN  2016-05-27
# 3584                                                NaN  2015-08-20
#
#                                       host_location  \
# 1              Boston, Massachusetts, United States
# 2              Boston, Massachusetts, United States
# 3              Boston, Massachusetts, United States
# 4              Boston, Massachusetts, United States
# 5              Boston, Massachusetts, United States
# 6              Milton, Massachusetts, United States
# 7              Boston, Massachusetts, United States
# 8              Boston, Massachusetts, United States
# 9              Boston, Massachusetts, United States
# 10             Boston, Massachusetts, United States
# 11                  Roslindale (part of Boston), MA
# 13             Boston, Massachusetts, United States
# 14             Boston, Massachusetts, United States
# 15             Boston, Massachusetts, United States
# 16             Boston, Massachusetts, United States
# 18             Boston, Massachusetts, United States
# 19             Boston, Massachusetts, United States
# 20             Boston, Massachusetts, United States
# 21             Boston, Massachusetts, United States
# 22             Boston, Massachusetts, United States
# 25             Boston, Massachusetts, United States
# 26    Boston Massachusetts, Roslindale Neighborhood
# 27             Boston, Massachusetts, United States
# 28             Boston, Massachusetts, United States
# 29                  Roslindale (part of Boston), MA
# 30             Boston, Massachusetts, United States
# 31             Boston, Massachusetts, United States
# 32             Boston, Massachusetts, United States
# 33             Boston, Massachusetts, United States
# 34             Boston, Massachusetts, United States
# ...                                             ...
# 3552       Somerville, Massachusetts, United States
# 3553       Somerville, Massachusetts, United States
# 3554                                             US
# 3555           Boston, Massachusetts, United States
# 3556       Somerville, Massachusetts, United States
# 3557           Boston, Massachusetts, United States
# 3558       Newport Beach, California, United States
# 3559           Boston, Massachusetts, United States
# 3560       Somerville, Massachusetts, United States
# 3561                                             US
# 3562          Ashland, Massachusetts, United States
# 3563                                             US
# 3564       Somerville, Massachusetts, United States
# 3566           Boston, Massachusetts, United States
# 3568       Somerville, Massachusetts, United States
# 3569           Boston, Massachusetts, United States
# 3570           Boston, Massachusetts, United States
# 3572                       Montreal, Quebec, Canada
# 3573       Somerville, Massachusetts, United States
# 3574                                             US
# 3575       Somerville, Massachusetts, United States
# 3576       Somerville, Massachusetts, United States
# 3577        Brookline, Massachusetts, United States
# 3578           Boston, Massachusetts, United States
# 3579           Boston, Massachusetts, United States
# 3580       Somerville, Massachusetts, United States
# 3581                                             US
# 3582              New York, New York, United States
# 3583       Somerville, Massachusetts, United States
# 3584       Somerville, Massachusetts, United States
#
#                                              host_about  host_response_time  \
# 1     I live in Boston and I like to travel and have...      within an hour
# 2     I am a middle-aged, single male with a wide ra...  within a few hours
# 3     My husband and I live on the property.  He’s a...  within a few hours
# 4     I work full time for a public school district....      within an hour
# 5                                                   NaN  within a few hours
# 6     American, Retired Banker. I travel a lot and a...      within an hour
# 7     My husband, Alan, and I are empty nesters and ...  within a few hours
# 8                          An avid lover of street art!      within an hour
# 9     Hi, I am a thirty something, happy-go-lucky ki...      within an hour
# 10                                                  NaN        within a day
# 11    Bon Jour, Bom Dia, Good Day,\r\n\r\nI'm a mid-...      within an hour
# 13                               A life-long Bostonian.      within an hour
# 14    As a Program Director for Viking River Cruises...        within a day
# 15    I am a self-employed professional. I work as a...      within an hour
# 16    My husband, John is an artist and retired adve...  within a few hours
# 18                                                  NaN        within a day
# 19                                                  NaN        within a day
# 20    I am an easy going person and enjoy the compan...  within a few hours
# 21    Judy and I are newlyweds and empty-nesters.  R...      within an hour
# 22    I am a self-employed professional. I work as a...      within an hour
# 25    I'm an architect and work out of my home.\r\nI...      within an hour
# 26    Artist who travels quite a bit. Easy going , q...      within an hour
# 27                                                  NaN  within a few hours
# 28    I am very outdoors oriented and love spending ...        within a day
# 29    Bon Jour, Bom Dia, Good Day,\r\n\r\nI'm a mid-...      within an hour
# 30    Laid back guy who enjoys seeing new parts of t...  within a few hours
# 31                                                  NaN      within an hour
# 32                                                  NaN                 NaN
# 33                                                  NaN        within a day
# 34    Born on a ranch in Nevada and now a resident o...  within a few hours
# ...                                                 ...                 ...
# 3552  I just moved to the city. I absolutely love it...      within an hour
# 3553                                                NaN      within an hour
# 3554                                                NaN  within a few hours
# 3555           Biomedical researcher. With PhD and MD.   within a few hours
# 3556                                                NaN      within an hour
# 3557  Hi there, \r\nI am Maureen. I moved to Boston ...        within a day
# 3558  We live in Newport beach.\r\nWe are couple wit...  within a few hours
# 3559                                                NaN  within a few hours
# 3560                                                NaN      within an hour
# 3561                                                NaN                 NaN
# 3562                                                NaN                 NaN
# 3563  We are listing our second home, located only a...                 NaN
# 3564                                                NaN      within an hour
# 3566                                                NaN      within an hour
# 3568                                                NaN      within an hour
# 3569                                                NaN      within an hour
# 3570  我喜欢帮助旅游者; I enjoy to help my friends.\r\n我的客房离...      within an hour
# 3572  We think a great trip starts with a 5-star hos...  within a few hours
# 3573  I just moved to the city. I absolutely love it...      within an hour
# 3574                                                NaN      within an hour
# 3575                                                NaN      within an hour
# 3576                                                NaN        within a day
# 3577  I am a professional woman, married to a wonder...                 NaN
# 3578  An Accounting Professor, Certified Fraud Exami...      within an hour
# 3579                                                NaN                 NaN
# 3580                                                NaN      within an hour
# 3581                                        this is Ivy  a few days or more
# 3582                                                NaN        within a day
# 3583  Hi, I am very friendly, helpful, positive and ...      within an hour
# 3584  I just moved to the city. I absolutely love it...      within an hour
#
#      host_response_rate host_acceptance_rate host_is_superhost  \
# 1                  100%                 100%                 f
# 2                  100%                  88%                 t
# 3                  100%                  50%                 f
# 4                  100%                 100%                 t
# 5                  100%                  95%                 t
# 6                   98%                  96%                 f
# 7                  100%                 100%                 t
# 8                  100%                 100%                 t
# 9                  100%                 100%                 t
# 10                  83%                 100%                 f
# 11                 100%                  89%                 t
# 13                 100%                  97%                 f
# 14                  75%                 100%                 f
# 15                 100%                  79%                 f
# 16                 100%                 100%                 f
# 18                 100%                 100%                 t
# 19                 100%                 100%                 t
# 20                 100%                  94%                 t
# 21                 100%                 100%                 f
# 22                 100%                  79%                 f
# 25                 100%                  92%                 t
# 26                 100%                 100%                 f
# 27                 100%                 100%                 t
# 28                  60%                 100%                 f
# 29                 100%                  89%                 t
# 30                  95%                 100%                 f
# 31                 100%                 100%                 f
# 32                  NaN                  NaN                 f
# 33                 100%                 100%                 t
# 34                 100%                  71%                 f
# ...                 ...                  ...               ...
# 3552               100%                  95%                 f
# 3553                96%                 100%                 f
# 3554               100%                 100%                 f
# ...
# 26                       9.0                  9.0                f      NaN
# 27                      10.0                 10.0                f      NaN
# 28                       9.0                  9.0                f      NaN
# 29                       9.0                 10.0                f      NaN
# 30                       9.0                  9.0                f      NaN
# 31                       9.0                 10.0                f      NaN
# 32                       NaN                  NaN                f      NaN
# 33                       9.0                 10.0                f      NaN
# 34                      10.0                 10.0                f      NaN
# ...                      ...                  ...              ...      ...
# 3552                     NaN                  NaN                f      NaN
# 3553                     NaN                  NaN                f      NaN
# 3554                    10.0                 10.0                f      NaN
# 3555                    10.0                  9.0                f      NaN
# 3556                     NaN                  NaN                f      NaN
# 3557                     NaN                  NaN                f      NaN
# 3558                     NaN                  NaN                f      NaN
# 3559                    10.0                 10.0                f      NaN
# 3560                     NaN                  NaN                f      NaN
# 3561                     NaN                  NaN                f      NaN
# 3562                     NaN                  NaN                f      NaN
# 3563                     NaN                  NaN                f      NaN
# 3564                     NaN                  NaN                f      NaN
# 3566                     NaN                  NaN                f      NaN
# 3568                     6.0                  6.0                f      NaN
# 3569                     NaN                  NaN                f      NaN
# 3570                     9.0                  9.0                f      NaN
# 3572                     NaN                  NaN                f      NaN
# 3573                    10.0                 10.0                f      NaN
# 3574                    10.0                  8.0                f      NaN
# 3575                     8.0                  7.0                f      NaN
# 3576                     NaN                  NaN                f      NaN
# 3577                     NaN                  NaN                f      NaN
# 3578                    10.0                 10.0                f      NaN
# 3579                     NaN                  NaN                f      NaN
# 3580                     8.0                  9.0                f      NaN
# 3581                     NaN                  NaN                f      NaN
# 3582                     NaN                  NaN                f      NaN
# 3583                     8.0                  7.0                f      NaN
# 3584                     NaN                  NaN                f      NaN
#
#       jurisdiction_names instant_bookable cancellation_policy  \
# 1                    NaN                t            moderate
# 2                    NaN                f            moderate
# 3                    NaN                f            moderate
# 4                    NaN                f            flexible
# 5                    NaN                f            flexible
# 6                    NaN                f              strict
# 7                    NaN                f            moderate
# 8                    NaN                f            moderate
# 9                    NaN                f              strict
# 10                   NaN                f            flexible
# 11                   NaN                f            flexible
# 13                   NaN                f            moderate
# 14                   NaN                f            moderate
# 15                   NaN                t              strict
# 16                   NaN                f            flexible
# 18                   NaN                f              strict
# 19                   NaN                f              strict
# 20                   NaN                f            flexible
# 21                   NaN                t            moderate
# 22                   NaN                t              strict
# 25                   NaN                f            moderate
# 26                   NaN                f              strict
# 27                   NaN                f            moderate
# 28                   NaN                f            flexible
# 29                   NaN                f            flexible
# 30                   NaN                f            flexible
# 31                   NaN                t              strict
# 32                   NaN                t            flexible
# 33                   NaN                f              strict
# 34                   NaN                f            flexible
# ...                  ...              ...                 ...
# 3552                 NaN                t            flexible
# 3553                 NaN                t              strict
# 3554                 NaN                f            flexible
# 3555                 NaN                f            moderate
# 3556                 NaN                t              strict
# 3557                 NaN                f            flexible
# 3558                 NaN                f              strict
# 3559                 NaN                f            moderate
# 3560                 NaN                f              strict
# 3561                 NaN                f              strict
# 3562                 NaN                f            flexible
# 3563                 NaN                f            moderate
# 3564                 NaN                t              strict
# 3566                 NaN                f            flexible
# 3568                 NaN                t              strict
# 3569                 NaN                f            flexible
# 3570                 NaN                f              strict
# 3572                 NaN                t              strict
# 3573                 NaN                t            flexible
# 3574                 NaN                f            moderate
# 3575                 NaN                t              strict
# 3576                 NaN                f            flexible
# 3577                 NaN                f            flexible
# 3578                 NaN                t              strict
# 3579                 NaN                f            flexible
# 3580                 NaN                t              strict
# 3581                 NaN                f              strict
# 3582                 NaN                f            flexible
# 3583                 NaN                f              strict
# 3584                 NaN                t            flexible
#
#      require_guest_profile_picture require_guest_phone_verification  \
# 1                                f                                f
# 2                                t                                f
# 3                                f                                f
# 4                                f                                f
# 5                                f                                f
# 6                                f                                f
# 7                                t                                t
# 8                                f                                f
# 9                                f                                f
# 10                               f                                f
# 11                               f                                f
# 13                               f                                f
# 14                               f                                f
# 15                               f                                f
# 16                               f                                f
# 18                               f                                f
# 19                               f                                f
# 20                               f                                f
# 21                               f                                f
# 22                               f                                f
# 25                               f                                f
# 26                               f                                f
# 27                               f                                f
# 28                               f                                f
# 29                               f                                f
# 30                               f                                f
# 31                               f                                f
# 32                               f                                f
# 33                               f                                f
# 34                               f                                f
# ...                            ...                              ...
# 3552                             f                                f
# 3553                             f                                f
# 3554                             f                                f
# 3555                             f                                f
# 3556                             f                                f
# 3557                             f                                f
# 3558                             f                                f
# 3559                             f                                f
# 3560                             f                                f
# 3561                             f                                f
# 3562                             f                                f
# 3563                             f                                f
# 3564                             f                                f
# 3566                             f                                f
# 3568                             f                                f
# 3569                             f                                f
# 3570                             f                                f
# 3572                             f                                f
# 3573                             f                                f
# 3574                             f                                f
# 3575                             f                                f
# 3576                             f                                f
# 3577                             f                                f
# 3578                             f                                f
# 3579                             f                                f
# 3580                             f                                f
# 3581                             f                                f
# 3582                             f                                f
# 3583                             f                                f
# 3584                             f                                f
#
#       calculated_host_listings_count  reviews_per_month   avg_price
# 1                                  1               1.30   67.813370
# 2                                  1               0.47   65.000000
# 3                                  1               1.00   75.000000
# 4                                  1               2.25   79.000000
# 5                                  1               1.70   75.000000
# 6                                  3               4.00  111.755814
# 7                                  2               2.38   75.000000
# 8                                  1               5.36   59.363112
# 9                                  2               1.01  252.925234
# 10                                 1               0.36   54.311953
# 11                                 2               0.48   57.000000
# 13                                 1               4.93  150.000000
# 14                                 1               0.56  145.000000
# 15                                 2               1.16   60.000000
# 16                                 1               1.00  166.418338
# 18                                 3                NaN   49.000000
# 19                                 3               0.29   49.000000
# 20                                 3               1.24   40.075301
# 21                                 1               5.93  126.449275
# 22                                 2               0.63   70.000000
# 25                                 2               1.13   95.000000
# 26                                 1               1.06   90.000000
# 27                                 1               4.02   99.953271
# 28                                 1               0.21  100.000000
# 29                                 2               0.58   67.209677
# 30                                 1               1.93   55.000000
# 31                                 1               0.38  199.008499
# 32                                 1                NaN  150.000000
# 33                                 3               0.72   49.000000
# 34                                 1               0.59   75.000000
# ...                              ...                ...         ...
# 3552                               3                NaN   46.852368
# 3553                               8                NaN   70.700000
# 3554                               1               2.00  125.000000
# 3555                               1               4.00   39.000000
# 3556                               8                NaN   70.667590
# 3557                               1                NaN   60.000000
# 3558                               1                NaN  197.408759
# 3559                               1               1.28  285.986301
# 3560                               8                NaN  249.000000
# 3561                               1                NaN   72.515942
# 3562                               1                NaN  179.000000
# 3563                               1                NaN  199.000000
# 3564                               8                NaN   75.000000
# 3566                               1                NaN   75.120448
# 3568                               8               1.00   70.655556
# 3569                               1                NaN  200.000000
# 3570                               6               0.29   74.894737
# 3572                              58                NaN  576.558140
# 3573                               3               2.00   64.547059
# 3574                               2               1.00   68.000000
# 3575                               8               0.33   70.702247
# 3576                               1                NaN  137.945455
# 3577                               1                NaN  122.222222
# 3578                               2               2.00   85.000000
# 3579                               1                NaN   95.739130
# 3580                               8               0.34   70.657303
# 3581                               2                NaN  150.000000
# 3582                               1                NaN  123.275000
# 3583                               1               2.00   59.000000
# 3584                               3                NaN   64.781818
#
# [2906 rows x 74 columns]

# %%
# how many missing values are there in calculated_host_listings_count
price_reg['calculated_host_listings_count'].isnull().sum()
# Out:
# 0

# %%
# create new data frame with listings only containing listings that are the only listing of a host in Boston
host_1 = price_reg[price_reg['calculated_host_listings_count'] == 1]

host_more = price_reg[price_reg['calculated_host_listings_count'] > 1]

# %%
# distribution of number of listings per host (for hosts who have more than 1 listing)
plt.figure(figsize=(15,6))
plt.hist(host_more['calculated_host_listings_count'], bins=30);

# %% [markdown]
# ### Differences between single-listing and multi-listings

# %% [markdown]
# #### Average prices and neighborhood distributions

# %%
# average prices
mean_1 = host_1['avg_price'].mean()
mean_more = host_more['avg_price'].mean()

print(mean_1)
print(mean_more)
# Out:
# 176.27540225646425
# 211.63297667937584

# %%
# plotting number of properties per neighborhood split by single- and multi-listings
plt.figure(figsize=(15,6))

plt.subplot(1,2,1)
sns.countplot(host_1['neighbourhood_cleansed'], order=neighborhood_price['neighborhood'])
plt.xticks(rotation=90);

plt.subplot(1,2,2)
sns.countplot(host_more['neighbourhood_cleansed'], order=neighborhood_price['neighborhood'])
plt.xticks(rotation=90);

# %%
# creating lists identifying above and below average price neighborhoods
below_avg = [x for x, y in zip(neighborhood_price['neighborhood'], neighborhood_price['normalize']) if y < 0]
above_avg = [x for x, y in zip(neighborhood_price['neighborhood'], neighborhood_price['normalize']) if y > 0]
below_avg
# Out:
# ['Mattapan',
#  'Hyde Park',
#  'Dorchester',
#  'Roslindale',
#  'West Roxbury',
#  'East Boston',
#  'Allston',
#  'Brighton',
#  'Longwood Medical Area',
#  'Jamaica Plain',
#  'Roxbury',
#  'Mission Hill',
#  'Charlestown']

# %%
# get ratio of below average and above average neighborhoods
def temp_df(df):
    '''
    creating temporary dataframes for further analysis on property ratio in above and below average neighborhoods
    INPUT: df = data frame containing properties with either host who only has one listing or
           data frame containing properties with host who has more than one listing on Airbnb
    OUTPUT: dataframe 
    '''
    temp_df = pd.DataFrame(df.groupby('neighbourhood_cleansed')['name'].count())
    temp_df = temp_df.reset_index()
    return temp_df

def avg_ratio(df, abv_blw):
    '''
    calculating number of properties within above or below average neighborhoods
    INPUT: df = dataframe with count of properties per neighborhood, abv_blw = list of above or below average neighborhoods
    OUTPUT: count of properties
    '''
    count = 0
    for neigh in abv_blw:
        for row in df['neighbourhood_cleansed']:
            if neigh == row:
                loc_row = df[df['neighbourhood_cleansed']== neigh].index.item()
                count += df['name'][loc_row]
    return count

# %%
# calculating the ratios
temp_1_df = temp_df(host_1)
temp_more_df = temp_df(host_more)

below_host_1 = avg_ratio(temp_1_df, below_avg)
above_host_1 = avg_ratio(temp_1_df, above_avg)
host_1_ratio = below_host_1/(below_host_1+above_host_1)

below_host_more = avg_ratio(temp_more_df, below_avg)
above_host_more =  avg_ratio(temp_more_df, above_avg)
host_more_ratio =  below_host_more/(below_host_more + above_host_more) 

print(host_1_ratio)
print(host_more_ratio)
# Out:
# 0.5281456953642384
# 0.4558303886925795

# %% [markdown]
# #### Average ratings

# %%
# average ratings between single- and multi-listings
host_1_mean_rate = host_1['review_scores_rating'].mean()
host_more_mean_rate = host_more['review_scores_rating'].mean()

print(host_more_mean_rate)
print(host_1_mean_rate)
# Out:
# 90.43426883308751
# 93.90981963927808

# %%
# distribution of average ratings based on number of listings per host
host_more_rate = host_more.groupby('calculated_host_listings_count')['review_scores_rating'].mean()

print(host_more_rate)
# Out:
# calculated_host_listings_count
# 2      92.349396
# 3      91.478376
# 4      89.580795
# 5      90.194283
# 6      90.975100
# 7      87.795774
# 8      88.882139
# 9      85.841342
# 10     92.332710
# 11     85.575758
# 12     96.083333
# 13     91.103284
# 14     91.838363
# 15     82.581142
# 17     89.933443
# 19     88.549172
# 20     90.295232
# 24     91.790395
# 25     91.283191
# 50     91.101595
# 58     91.240528
# 61     88.407214
# 79     88.981190
# 136    88.359653
# Name: review_scores_rating, dtype: float64

# %%
# plotting rating distribution split by single- and multi-listing properties
plt.figure(figsize=(15,6))
           
plt.subplot(1,2,1)
plt.hist(host_1['review_scores_rating'], bins=50)
plt.title('Single-listing rating distribution')
plt.xlabel('Overall rating')
plt.ylabel('Number of properties')

plt.subplot(1,2,2)
plt.hist(host_more['review_scores_rating'], bins=50)
plt.title('Multi-listing rating distribution')
plt.xlabel('Overall rating')
plt.ylabel('Number of properties');

# %%
# imputing missing values in the review_scores_rating column with the mean
host_1['review_scores_rating'] = host_1['review_scores_rating'].fillna(host_1_mean_rate)
host_more['review_scores_rating'] = host_more['review_scores_rating'].fillna(host_more_mean_rate)
# Out:
# 0
# C:\Users\julia\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\julia\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Do Welch's t-test for both samples and all ratings
stat, p = ttest_ind(host_more['review_scores_rating'], host_1['review_scores_rating'], equal_var=False)

# Printing the t-statistic and the p-value
print(stat, p)
# Out:
# -12.205079437640325 1.9068745426359934e-33

# %% [markdown]
# This tells me that the two distributions of properties with single-listing hosts and properties with multi-listing hosts are indeed different and thus, lower ratings in the group of multi-listings are statistically significant

# %%
# average price per neighborhood split by host_1 and host_more
